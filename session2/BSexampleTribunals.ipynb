# %% [markdown]
# # Python case study: tribunals (inc. dealing with dates)
#
# When we import or grab dates they are often treated as text strings, when we actually want to treat them *as* dates.
#
# In this notebook we scrape some data that includes dates, and then convert the dates to a 'datetime' variable so we can perform related actions (such as extracting a month, or identifying which day of the week a date fell on).
#
# The page we want to scrape is [employment tribunal decisions](https://www.gov.uk/employment-tribunal-decisions).

# %% [markdown]
# ## Scrape the page
#
# First we scrape the data - we are going to scrape a page of tribunal decisions.

# %%
#importing requests to fetch URLs
import requests
#importing beautiful soup's library for drilling into webpages
from bs4 import BeautifulSoup
#and pandas for storing data
import pandas as pd


#fetch URL
page = requests.get("https://www.gov.uk/employment-tribunal-decisions")

#command beautiful soup to parse the page
soup = BeautifulSoup(page.content,'html.parser')
#show the soup!
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 9]><html class="lte-ie8 govuk-template" lang="en"><![endif]--><!--[if gt IE 8]><!--><html class="govuk-template" lang="en">
# <!--<![endif]-->
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Find decisions on Employment Tribunal cases in England, Wales and Scotland." property="og:description"/>
# <meta content="Employment tribunal decisions" property="og:title"/>
# <meta content="https://www.gov.uk/employment-tribunal-decisions" property="og:url"/>
# <meta content="article" property="og:type"/>
# <meta content="GOV.UK" property="og:site_name"/>
# <meta content="" data-module="ga4-scroll-tracker" name="govuk:scroll-tracker"/>
# <meta content="Employment tribunal decisions - GOV.UK" name="govuk:base_title"/>
# <meta content="103723" name="govuk:search-result-count"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="&lt;EA73&gt;&lt;CO1133&gt;" name="govuk:analytics:organisations"/>
# <meta content="2023-02-07T11:26:26Z" name="govuk:public-updated-at"/>
# <meta content="2023-08-22T15:00:19Z" name="govuk:updated-at"/>
# <meta content="2017-02-08T16:15:17Z" name="govuk:first-published-at"/>
# <meta content="true" name="govuk:static-analytics:strip-postcodes"/>
# <meta content="1b5e08c8-ddde-4637-9375-f79e085ba6d5" name="govuk:content-id"/>
# <meta content="finder" name="govuk:schema-name"/>
# <meta content="finder-frontend" name="govuk:rendering-app"/>
# <meta content="specialist-publisher" name="govuk:publishing-app"/>
# <meta content="finder" name="govuk:format"/>
# <meta content="Find decisions on Employment Tribunal cases in England, Wales and Scotland." name="description"/>
# <meta charset="utf-8"/>
# <title>Employment tribunal decisions - GOV.UK</title>
# <script async="async" src="/assets/static/govuk_publishing_components/vendor/lux/lux-measurer-505eef3e243b1d08ea7c4b945ebe1ae146d896db61366e415b30cc1bcd84cbdc.js"></script>
# <script async="async" data-lux-reporter-script="/assets/static/govuk_publishing_components/vendor/lux/lux-reporter-93cb22329ce3a4f8c149e497043c275d4874e33c0e1d39aa43767ef93aadb7d4.js" src="/assets/static/govuk_publishing_components/rum-loader-c53469dcb841d7b228c914a2e8bdcf3b831a578adf7d4f21cf9da5b85df7381e.js"></script>
# <meta content="35.15.0" name="govuk:components_gem_version"/>
# <script src="/assets/static/govuk_publishing_components/load-analytics-e735b57e890b394272cd64d66cf332bb331825ed21c758ef3449d3942b1838e0.js"></script>
# <link href="/assets/static/application-7517dc22e248f0f2b41fe04ad40292b596959b33f03028cbb35500285a4d8fda.css" media="all" rel="stylesheet"/>
# <!--[if lt IE 9]><script src="/assets/static/govuk_publishing_components/ie-94963d6661190bc897905bbbe222a31c7ca0aff3a3b9f808ba15d4cd90780a9b.js" crossorigin="anonymous" integrity="sha256-pFJFRKU9V6fiWbS7lmucMlV8mMkgt35S0JMEZCtoQBo="></script><![endif]-->
# <link href="/assets/static/favicon-9ed7849c462c53aa2cdf1690eb257e801ecbf5696d1d0928868c5b032b4adb36.ico" rel="shortcut icon" type="image/x-icon"/>
# <link color="#0b0c0c" href="/assets/static/govuk-mask-icon-a409a4db4a5e72c99ae3916653710064c43eb4be35821f79c07c5156e7dc5808.svg" rel="mask-icon"/>
# <link href="/assets/static/govuk-apple-touch-icon-180x180-026deaa34fa328ae5f1f519a37dbd15e6555c5086e1ba83986cd0827a7209902.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/assets/static/govuk-apple-touch-icon-167x167-a44a5b317f51a61950697fbe6c61ffe3b5acdd89de60ef70429daa32881d5279.png" rel="apple-touch-icon" sizes="167x167"/>
# <link href="/assets/static/govuk-apple-touch-icon-152x152-828a839e5c83de19f98014eef54cec77aa11063a23ce321970d6f9310eeabb6c.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="/assets/static/govuk-apple-touch-icon-5f801db05920bd1eb2b27a7a90328599bb16b6344c3213795af0f20d3ca179b0.png" rel="apple-touch-icon"/>
# <meta content="#0b0c0c" name="theme-color"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="/assets/static/govuk-opengraph-image-dade2dad5775023b0568381c4c074b86318194edb36d3d68df721eea7deeac4b.png" property="og:image"/>
# <link href="/assets/finder-frontend/application-a24eabe5bc811f68921fe4e58dc2eb880955518f2483840085fa3906c50e682f.css" media="all" rel="stylesheet"/>
# <link href="/assets/finder-frontend/govuk_publishing_components/components/_phase-banner-e77b304bc3e6f26ff7907f802dd4866c516c91922ddc4de5fc2ca751541f6975.css" rel="stylesheet"/>
# <link href="/assets/finder-frontend/govuk_publishing_components/components/_metadata-353cb9a5f4ebea8bc16dd77959790cb8efa6ccb4a3ad372fc51c0295fbd7819a.css" rel="stylesheet"/>
# <link href="/assets/finder-frontend/govuk_publishing_components/components/_govspeak-84c18982093893cf27d27294cda113922ada58b2134516830fbb44bfc7486231.css" rel="stylesheet"/>
# <link href="/assets/finder-frontend/components/_mobile-filters-c47c35d057853591a39f3d50f926357680a38ffda09231041cff6e91b6cd9a8c.css" rel="stylesheet"/>
# <link href="/assets/finder-frontend/components/_option-select-ce807c96eab66ae45233f60dcf2304b23704c268515a289c4bacc7a6e939cb90.css" rel="stylesheet"/>
# <link href="/assets/finder-frontend/govuk_publishing_components/components/_checkboxes-a959df7639f79a50edda8c13ef2d6a0c43f142549eac7eb9d99dfb96d3c0722b.css" rel="stylesheet"/>
# <link href="/assets/finder-frontend/components/_expander-557f3fc4b49904d86bf828456296fc43cfdfd7ac3b288128b24c29d29a925099.css" rel="stylesheet"/>
# <link href="/assets/finder-frontend/govuk_publishing_components/components/_subscription-links-5eb8208f164d09f00df0475473e41924213aa75d11f4587538badaf756e1e892.css" rel="stylesheet"/>
# <link href="/assets/finder-frontend/govuk_publishing_components/components/_document-list-88c1c3b06c7f923656e2cc115e396e04c81a7211d321c288e3411c9bb66c19f6.css" rel="stylesheet"/>
# <link href="/assets/finder-frontend/govuk_publishing_components/components/_previous-and-next-navigation-53583b41438b3a57514bbbe15bb4d2c53b13363308af23b7b1e4ac4819b8e222.css" rel="stylesheet"/>
# <link href="/employment-tribunal-decisions.atom" rel="alternate" title="ATOM" type="application/atom+xml"/>
# <link href="/api/content/employment-tribunal-decisions" rel="alternate" type="application/json"/>
# <link href="https://www.gov.uk/employment-tribunal-decisions" rel="canonical"/>
# <meta content="finder-frontend" name="govuk:rendering-application"/>
# </head>
# <body class="gem-c-layout-for-public govuk-template__body">
# <script nonce="wVJOEFgmd1oIE9LWqmw5Aw==">
# //<![CDATA[
#       document.body.className = ((document.body.className) ? document.body.className + ' js-enabled' : 'js-enabled');
#
# //]]>
# </script> <a class="gem-c-skip-link govuk-skip-link govuk-!-display-none-print" data-module="govuk-skip-link" href="#content">Skip to main content</a>
# <div aria-label="Cookies on GOV.UK" class="gem-c-cookie-banner govuk-clearfix govuk-cookie-banner js-banner-wrapper" data-module="cookie-banner" data-nosnippet="" id="global-cookie-message" role="region">
# <div class="govuk-cookie-banner__message govuk-width-container">
# <div class="govuk-grid-row">
# <div class="govuk-grid-column-two-thirds">
# <h2 class="govuk-cookie-banner__heading govuk-heading-m">Cookies on GOV.UK</h2>
# <div class="govuk-cookie-banner__content gem-c-cookie-banner__confirmation" tabindex="-1">
# <span class="gem-c-cookie-banner__content"><p class="govuk-body">We use some essential cookies to make this website work.</p>
# <p class="govuk-body">We’d like to set additional cookies to understand how you use GOV.UK, remember your settings and improve government services.</p>
# <p class="govuk-body">We also use cookies set by other sites to help us deliver content from their services.</p></span>
# <p class="gem-c-cookie-banner__confirmation-message--accepted govuk-body" hidden="">You have accepted additional cookies. <span class="gem-c-cookie-banner__confirmation-message">You can <a class="govuk-link" data-module="gem-track-click" data-track-action="Cookie banner settings clicked from confirmation" data-track-category="cookieBanner" href="/help/cookies">change your cookie settings</a> at any time.</span></p>
# <p class="gem-c-cookie-banner__confirmation-message--rejected govuk-body" hidden="">You have rejected additional cookies. <span class="gem-c-cookie-banner__confirmation-message">You can <a class="govuk-link" data-module="gem-track-click" data-track-action="Cookie banner settings clicked from confirmation" data-track-category="cookieBanner" href="/help/cookies">change your cookie settings</a> at any time.</span></p>
# </div>
# </div>
# </div>
# <div class="js-confirmation-buttons govuk-button-group">
# <button class="gem-c-button govuk-button" data-accept-cookies="true" data-cookie-types="all" data-module="gem-track-click" data-track-action="Cookie banner accepted" data-track-category="cookieBanner" type="submit">Accept additional cookies</button>
# <button class="gem-c-button govuk-button" data-module="gem-track-click" data-reject-cookies="true" data-track-action="Cookie banner rejected" data-track-category="cookieBanner" type="submit">Reject additional cookies</button>
# <a class="govuk-link" href="/help/cookies">View cookies</a>
# </div>
# <div class="js-hide-button govuk-button-group" hidden="">
# <button class="gem-c-cookie-banner__hide-button govuk-button" data-hide-cookie-banner="true" data-module="gem-track-click" data-track-action="Hide cookie banner" data-track-category="cookieBanner">
#           Hide this message
#         </button>
# </div>
# </div>
# </div>
# <header class="gem-c-layout-super-navigation-header" data-ga4-expandable="" data-module="gem-track-click ga4-event-tracker ga4-link-tracker" data-track-links-only="" role="banner">
# <div class="gem-c-layout-super-navigation-header__container govuk-clearfix">
# <div class="govuk-width-container">
# <div class="gem-c-layout-super-navigation-header__header-logo">
# <a class="govuk-header__link govuk-header__link--homepage" data-ga4-link='{"event_name":"navigation","type":"header menu bar","external":"false","text":"GOV.UK","section":"Logo","index":{"index_link":1,"index_section":0,"index_section_count":2},"index_total":1}' data-track-action="logoLink" data-track-category="headerClicked" data-track-dimension="GOV.UK" data-track-dimension-index="29" data-track-label="https://www.gov.uk" href="https://www.gov.uk" id="logo" title="Go to the GOV.UK homepage">
# <span class="govuk-header__logotype">
# <!--[if gt IE 8]><!-->
# <svg aria-hidden="true" class="govuk-header__logotype-crown gem-c-layout-super-navigation-header__logotype-crown" focusable="false" height="30" viewbox="0 0 132 97" width="36" xmlns="http://www.w3.org/2000/svg">
# <path d="M25 30.2c3.5 1.5 7.7-.2 9.1-3.7 1.5-3.6-.2-7.8-3.9-9.2-3.6-1.4-7.6.3-9.1 3.9-1.4 3.5.3 7.5 3.9 9zM9 39.5c3.6 1.5 7.8-.2 9.2-3.7 1.5-3.6-.2-7.8-3.9-9.1-3.6-1.5-7.6.2-9.1 3.8-1.4 3.5.3 7.5 3.8 9zM4.4 57.2c3.5 1.5 7.7-.2 9.1-3.8 1.5-3.6-.2-7.7-3.9-9.1-3.5-1.5-7.6.3-9.1 3.8-1.4 3.5.3 7.6 3.9 9.1zm38.3-21.4c3.5 1.5 7.7-.2 9.1-3.8 1.5-3.6-.2-7.7-3.9-9.1-3.6-1.5-7.6.3-9.1 3.8-1.3 3.6.4 7.7 3.9 9.1zm64.4-5.6c-3.6 1.5-7.8-.2-9.1-3.7-1.5-3.6.2-7.8 3.8-9.2 3.6-1.4 7.7.3 9.2 3.9 1.3 3.5-.4 7.5-3.9 9zm15.9 9.3c-3.6 1.5-7.7-.2-9.1-3.7-1.5-3.6.2-7.8 3.7-9.1 3.6-1.5 7.7.2 9.2 3.8 1.5 3.5-.3 7.5-3.8 9zm4.7 17.7c-3.6 1.5-7.8-.2-9.2-3.8-1.5-3.6.2-7.7 3.9-9.1 3.6-1.5 7.7.3 9.2 3.8 1.3 3.5-.4 7.6-3.9 9.1zM89.3 35.8c-3.6 1.5-7.8-.2-9.2-3.8-1.4-3.6.2-7.7 3.9-9.1 3.6-1.5 7.7.3 9.2 3.8 1.4 3.6-.3 7.7-3.9 9.1zM69.7 17.7l8.9 4.7V9.3l-8.9 2.8c-.2-.3-.5-.6-.9-.9L72.4 0H59.6l3.5 11.2c-.3.3-.6.5-.9.9l-8.8-2.8v13.1l8.8-4.7c.3.3.6.7.9.9l-5 15.4v.1c-.2.8-.4 1.6-.4 2.4 0 4.1 3.1 7.5 7 8.1h.2c.3 0 .7.1 1 .1.4 0 .7 0 1-.1h.2c4-.6 7.1-4.1 7.1-8.1 0-.8-.1-1.7-.4-2.4V34l-5.1-15.4c.4-.2.7-.6 1-.9zM66 92.8c16.9 0 32.8 1.1 47.1 3.2 4-16.9 8.9-26.7 14-33.5l-9.6-3.4c1 4.9 1.1 7.2 0 10.2-1.5-1.4-3-4.3-4.2-8.7L108.6 76c2.8-2 5-3.2 7.5-3.3-4.4 9.4-10 11.9-13.6 11.2-4.3-.8-6.3-4.6-5.6-7.9 1-4.7 5.7-5.9 8-.5 4.3-8.7-3-11.4-7.6-8.8 7.1-7.2 7.9-13.5 2.1-21.1-8 6.1-8.1 12.3-4.5 20.8-4.7-5.4-12.1-2.5-9.5 6.2 3.4-5.2 7.9-2 7.2 3.1-.6 4.3-6.4 7.8-13.5 7.2-10.3-.9-10.9-8-11.2-13.8 2.5-.5 7.1 1.8 11 7.3L80.2 60c-4.1 4.4-8 5.3-12.3 5.4 1.4-4.4 8-11.6 8-11.6H55.5s6.4 7.2 7.9 11.6c-4.2-.1-8-1-12.3-5.4l1.4 16.4c3.9-5.5 8.5-7.7 10.9-7.3-.3 5.8-.9 12.8-11.1 13.8-7.2.6-12.9-2.9-13.5-7.2-.7-5 3.8-8.3 7.1-3.1 2.7-8.7-4.6-11.6-9.4-6.2 3.7-8.5 3.6-14.7-4.6-20.8-5.8 7.6-5 13.9 2.2 21.1-4.7-2.6-11.9.1-7.7 8.8 2.3-5.5 7.1-4.2 8.1.5.7 3.3-1.3 7.1-5.7 7.9-3.5.7-9-1.8-13.5-11.2 2.5.1 4.7 1.3 7.5 3.3l-4.7-15.4c-1.2 4.4-2.7 7.2-4.3 8.7-1.1-3-.9-5.3 0-10.2l-9.5 3.4c5 6.9 9.9 16.7 14 33.5 14.8-2.1 30.8-3.2 47.7-3.2z" fill="currentColor" fill-rule="evenodd">
# </path>
# </svg>
# <!--<![endif]-->
# <!--[if IE 8]>
#             <img src="/assets/static/govuk-logotype-crown-66ad9a9b8fca42cf0ba18979eef6afc2e8056d5f158ca9b27ce9afdf852aae87.png" alt="" class="govuk-header__logotype-crown-fallback-image" width="36" height="32">
#             <![endif]-->
# <span class="govuk-header__logotype-text">
#               GOV.UK
#             </span>
# </span>
# </a>
# </div>
# </div>
# <nav aria-labelledby="super-navigation-menu-heading" class="gem-c-layout-super-navigation-header__content" data-module="super-navigation-mega-menu">
# <h2 class="govuk-visually-hidden" id="super-navigation-menu-heading">
#         Navigation menu
#       </h2>
# <div class="govuk-width-container gem-c-layout-super-navigation-header__button-width-container">
# <div class="gem-c-layout-super-navigation-header__button-container">
# <div class="gem-c-layout-super-navigation-header__navigation-item">
# <a class="gem-c-layout-super-navigation-header__navigation-item-link" data-track-action="menuLink" data-track-category="headerClicked" data-track-dimension="Menu" data-track-dimension-index="29" data-track-label="/browse" href="/browse">
# <span class="gem-c-layout-super-navigation-header__navigation-item-link-inner">
#                 Menu
#               </span>
# </a>
# <button aria-controls="super-navigation-menu-df56d206" aria-expanded="false" aria-label="Show navigation menu" class="gem-c-layout-super-navigation-header__navigation-top-toggle-button" data-ga4-event='{"event_name":"select_content","type":"header menu bar","text":"Menu","index":{"index_section":1,"index_section_count":2},"section":"Menu"}' data-text-for-hide="Hide navigation menu" data-text-for-show="Show navigation menu" data-toggle-desktop-group="top" data-toggle-mobile-group="top" data-tracking-key="menu" hidden="hidden" id="super-navigation-menu-df56d206-toggle" type="button">
# <span class="gem-c-layout-super-navigation-header__navigation-top-toggle-button-inner">Menu</span>
# </button> </div>
# <div class="gem-c-layout-super-navigation-header__search-item">
# <button aria-controls="super-search-menu" aria-expanded="true" aria-label="Hide search menu" class="gem-c-layout-super-navigation-header__search-toggle-button" data-ga4-event='{"event_name":"select_content","type":"header menu bar","text":"Search","index":{"index_section":2,"index_section_count":2},"section":"Search"}' data-text-for-hide="Hide search menu" data-text-for-show="Show search menu" data-toggle-desktop-group="top" data-toggle-mobile-group="top" data-tracking-key="search" hidden="" id="super-search-menu-toggle" type="button">
# <span class="govuk-visually-hidden">
#                 Search GOV.UK
#               </span>
# <svg aria-hidden="true" class="gem-c-layout-super-navigation-header__search-toggle-button-link-icon" fill="none" focusable="false" height="27" viewbox="0 0 27 27" width="27" xmlns="http://www.w3.org/2000/svg">
# <circle cx="12.0161" cy="11.0161" r="8.51613" stroke="currentColor" stroke-width="3"></circle>
# <line stroke="currentColor" stroke-width="3" x1="17.8668" x2="26.4475" y1="17.3587" y2="25.9393"></line>
# </svg>
# <span aria-hidden="true" class="gem-c-layout-super-navigation-header__navigation-top-toggle-close-icon" focusable="false">
#                 ×
#               </span>
# </button>
# <a class="gem-c-layout-super-navigation-header__search-item-link" href="/search">
# <span class="govuk-visually-hidden">
#                 Search GOV.UK
#               </span>
# <svg aria-hidden="true" class="gem-c-layout-super-navigation-header__search-item-link-icon" fill="none" focusable="false" height="27" viewbox="0 0 27 27" width="27" xmlns="http://www.w3.org/2000/svg">
# <circle cx="12.0161" cy="11.0161" r="8.51613" stroke="currentColor" stroke-width="3"></circle>
# <line stroke="currentColor" stroke-width="3" x1="17.8668" x2="26.4475" y1="17.3587" y2="25.9393"></line>
# </svg>
# </a>
# </div>
# </div>
# </div>
# <div class="gem-c-layout-super-navigation-header__navigation-dropdown-menu" hidden="" id="super-navigation-menu-df56d206">
# <div class="govuk-width-container">
# <div class="govuk-grid-row gem-c-layout-super-navigation-header__navigation-items">
# <div class="govuk-grid-column-two-thirds-from-desktop gem-c-layout-super-navigation-header__column--services-and-information">
# <h3 class="govuk-heading-m gem-c-layout-super-navigation-header__column-header">
#                   Services and information
#                 </h3>
# <ul class="gem-c-layout-super-navigation-header__navigation-second-items gem-c-layout-super-navigation-header__navigation-second-items--services-and-information">
# <li class="gem-c-layout-super-navigation-header__dropdown-list-item">
# <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":1,"index_link":1,"index_section_count":4},"index_total":16,"section":"Services and information"}' data-track-action="servicesandinformationLink" data-track-category="headerClicked" data-track-dimension="Benefits" data-track-dimension-index="29" data-track-label="/browse/benefits" href="/browse/benefits">Benefits</a>
# </li>
# <li class="gem-c-layout-super-navigation-header__dropdown-list-item">
# <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":1,"index_link":2,"index_section_count":4},"index_total":16,"section":"Services and information"}' data-track-action="servicesandinformationLink" data-track-category="headerClicked" data-track-dimension="Births, death, marriages and care" data-track-dimension-index="29" data-track-label="/browse/births-deaths-marriages" href="/browse/births-deaths-marriages">Births, death, marriages and care</a>
# </li>
# <li class="gem-c-layout-super-navigation-header__dropdown-list-item">
# <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":1,"index_link":3,"index_section_count":4},"index_total":16,"section":"Services and information"}' data-track-action="servicesandinformationLink" data-track-category="headerClicked" data-track-dimension="Business and self-employed" data-track-dimension-index="29" data-track-label="/browse/business" href="/browse/business">Business and self-employed</a>
# </li>
# <li class="gem-c-layout-super-navigation-header__dropdown-list-item">
# <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":1,"index_link":4,"index_section_count":4},"index_total":16,"section":"Services and information"}' data-track-action="servicesandinformationLink" data-track-category="headerClicked" data-track-dimension="Childcare and parenting" data-track-dimension-index="29" data-track-label="/browse/childcare-parenting" href="/browse/childcare-parenting">Childcare and parenting</a>
# </li>
# <li class="gem-c-layout-super-navigation-header__dropdown-list-item">
# <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":1,"index_link":5,"index_section_count":4},"index_total":16,"section":"Services and information"}' data-track-action="servicesandinformationLink" data-track-category="headerClicked" data-track-dimension="Citizenship and living in the UK" data-track-dimension-index="29" data-track-label="/browse/citizenship" href="/browse/citizenship">Citizenship and living in the UK</a>
# </li>
# <li class="gem-c-layout-super-navigation-header__dropdown-list-item">
# <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":1,"index_link":6,"index_section_count":4},"index_total":16,"section":"Services and information"}' data-track-action="servicesandinformationLink" data-track-category="headerClicked" data-track-dimension="Crime, justice and the law" data-track-dimension-index="29" data-track-label="/browse/justice" href="/browse/justice">Crime, justice and the law</a>
# </li>
# <li class="gem-c-layout-super-navigation-header__dropdown-list-item">
# <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":1,"index_link":7,"index_section_count":4},"index_total":16,"section":"Services and information"}' data-track-action="servicesandinformationLink" data-track-category="headerClicked" data-track-dimension="Disabled people" data-track-dimension-index="29" data-track-label="/browse/disabilities" href="/browse/disabilities">Disabled people</a>
# </li>
# <li class="gem-c-layout-super-navigation-header__dropdown-list-item">
# <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":1,"index_link":8,"index_section_count":4},"index_total":16,"section":"Services and information"}' data-track-action="servicesandinformationLink" data-track-category="headerClicked" data-track-dimension="Driving and transport" data-track-dimension-index="29" data-track-label="/browse/driving" href="/browse/driving">Driving and transport</a>
# </li>
# <li class="gem-c-layout-super-navigation-header__dropdown-list-item">
# <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":1,"index_link":9,"index_section_count":4},"index_total":16,"section":"Services and information"}' data-track-action="servicesandinformationLink" data-track-category="headerClicked" data-track-dimension="Education and learning" data-track-dimension-index="29" data-track-label="/browse/education" href="/browse/education">Education and learning</a>
# </li>
# <li class="gem-c-layout-super-navigation-header__dropdown-list-item">
# <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":1,"index_link":10,"index_section_count":4},"index_total":16,"section":"Services and information"}' data-track-action="servicesandinformationLink" data-track-category="headerClicked" data-track-dimension="Employing people" data-track-dimension-index="29" data-track-label="/browse/employing-people" href="/browse/employing-people">Employing people</a>
# </li>
# <li class="gem-c-layout-super-navigation-header__dropdown-list-item">
# <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":1,"index_link":11,"index_section_count":4},"index_total":16,"section":"Services and information"}' data-track-action="servicesandinformationLink" data-track-category="headerClicked" data-track-dimension="Environment and countryside" data-track-dimension-index="29" data-track-label="/browse/environment-countryside" href="/browse/environment-countryside">Environment and countryside</a>
# </li>
# <li class="gem-c-layout-super-navigation-header__dropdown-list-item">
# <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":1,"index_link":12,"index_section_count":4},"index_total":16,"section":"Services and information"}' data-track-action="servicesandinformationLink" data-track-category="headerClicked" data-track-dimension="Housing and local services" data-track-dimension-index="29" data-track-label="/browse/housing-local-services" href="/browse/housing-local-services">Housing and local services</a>
# </li>
# <li class="gem-c-layout-super-navigation-header__dropdown-list-item">
# <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":1,"index_link":13,"index_section_count":4},"index_total":16,"section":"Services and information"}' data-track-action="servicesandinformationLink" data-track-category="headerClicked" data-track-dimension="Money and tax" data-track-dimension-index="29" data-track-label="/browse/tax" href="/browse/tax">Money and tax</a>
# </li>
# <li class="gem-c-layout-super-navigation-header__dropdown-list-item">
# <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":1,"index_link":14,"index_section_count":4},"index_total":16,"section":"Services and information"}' data-track-action="servicesandinformationLink" data-track-category="headerClicked" data-track-dimension="Passports, travel and living abroad" data-track-dimension-index="29" data-track-label="/browse/abroad" href="/browse/abroad">Passports, travel and living abroad</a>
# </li>
# <li class="gem-c-layout-super-navigation-header__dropdown-list-item">
# <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":1,"index_link":15,"index_section_count":4},"index_total":16,"section":"Services and information"}' data-track-action="servicesandinformationLink" data-track-category="headerClicked" data-track-dimension="Visas and immigration" data-track-dimension-index="29" data-track-label="/browse/visas-immigration" href="/browse/visas-immigration">Visas and immigration</a>
# </li>
# <li class="gem-c-layout-super-navigation-header__dropdown-list-item">
# <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":1,"index_link":16,"index_section_count":4},"index_total":16,"section":"Services and information"}' data-track-action="servicesandinformationLink" data-track-category="headerClicked" data-track-dimension="Working, jobs and pensions" data-track-dimension-index="29" data-track-label="/browse/working" href="/browse/working">Working, jobs and pensions</a>
# </li>
# </ul>
# </div>
# <div class="govuk-grid-column-one-third-from-desktop gem-c-layout-super-navigation-header__column--government-activity">
# <h3 class="govuk-heading-m gem-c-layout-super-navigation-header__column-header">
#                   Government activity
#                 </h3>
# <ul class="gem-c-layout-super-navigation-header__navigation-second-items gem-c-layout-super-navigation-header__navigation-second-items--government-activity">
# <li class="gem-c-layout-super-navigation-header__dropdown-list-item">
# <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link gem-c-layout-super-navigation-header__navigation-second-item-link--with-description" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":2,"index_link":1,"index_section_count":4},"index_total":6,"section":"Government activity"}' data-track-action="governmentactivityLink" data-track-category="headerClicked" data-track-dimension="Departments" data-track-dimension-index="29" data-track-label="/government/organisations" href="/government/organisations">Departments</a>
# <p class="gem-c-layout-super-navigation-header__navigation-second-item-description">Departments, agencies and public bodies</p>
# </li>
# <li class="gem-c-layout-super-navigation-header__dropdown-list-item">
# <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link gem-c-layout-super-navigation-header__navigation-second-item-link--with-description" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":2,"index_link":2,"index_section_count":4},"index_total":6,"section":"Government activity"}' data-track-action="governmentactivityLink" data-track-category="headerClicked" data-track-dimension="News" data-track-dimension-index="29" data-track-label="/search/news-and-communications" href="/search/news-and-communications">News</a>
# <p class="gem-c-layout-super-navigation-header__navigation-second-item-description">News stories, speeches, letters and notices</p>
# </li>
# <li class="gem-c-layout-super-navigation-header__dropdown-list-item">
# <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link gem-c-layout-super-navigation-header__navigation-second-item-link--with-description" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":2,"index_link":3,"index_section_count":4},"index_total":6,"section":"Government activity"}' data-track-action="governmentactivityLink" data-track-category="headerClicked" data-track-dimension="Guidance and regulation" data-track-dimension-index="29" data-track-label="/search/guidance-and-regulation" href="/search/guidance-and-regulation">Guidance and regulation</a>
# <p class="gem-c-layout-super-navigation-header__navigation-second-item-description">Detailed guidance, regulations and rules</p>
# </li>
# <li class="gem-c-layout-super-navigation-header__dropdown-list-item">
# <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link gem-c-layout-super-navigation-header__navigation-second-item-link--with-description" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":2,"index_link":4,"index_section_count":4},"index_total":6,"section":"Government activity"}' data-track-action="governmentactivityLink" data-track-category="headerClicked" data-track-dimension="Research and statistics" data-track-dimension-index="29" data-track-label="/search/research-and-statistics" href="/search/research-and-statistics">Research and statistics</a>
# <p class="gem-c-layout-super-navigation-header__navigation-second-item-description">Reports, analysis and official statistics</p>
# </li>
# <li class="gem-c-layout-super-navigation-header__dropdown-list-item">
# <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link gem-c-layout-super-navigation-header__navigation-second-item-link--with-description" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":2,"index_link":5,"index_section_count":4},"index_total":6,"section":"Government activity"}' data-track-action="governmentactivityLink" data-track-category="headerClicked" data-track-dimension="Policy papers and consultations" data-track-dimension-index="29" data-track-label="/search/policy-papers-and-consultations" href="/search/policy-papers-and-consultations">Policy papers and consultations</a>
# <p class="gem-c-layout-super-navigation-header__navigation-second-item-description">Consultations and strategy</p>
# </li>
# <li class="gem-c-layout-super-navigation-header__dropdown-list-item">
# <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link gem-c-layout-super-navigation-header__navigation-second-item-link--with-description" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":2,"index_link":6,"index_section_count":4},"index_total":6,"section":"Government activity"}' data-track-action="governmentactivityLink" data-track-category="headerClicked" data-track-dimension="Transparency" data-track-dimension-index="29" data-track-label="/search/transparency-and-freedom-of-information-releases" href="/search/transparency-and-freedom-of-information-releases">Transparency</a>
# <p class="gem-c-layout-super-navigation-header__navigation-second-item-description">Data, Freedom of Information releases and corporate reports</p>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="gem-c-layout-super-navigation-header__navigation-dropdown-menu" hidden="" id="super-search-menu">
# <div class="govuk-width-container gem-c-layout-super-navigation-header__search-container gem-c-layout-super-navigation-header__search-items">
# <h3 class="govuk-visually-hidden">
#             Search
#           </h3>
# <div class="govuk-grid-row">
# <div class="govuk-grid-column-full">
# <form action="/search" aria-label="Site-wide" class="gem-c-layout-super-navigation-header__search-form" data-ga4-form='{ "event_name": "search", "type": "header menu bar", "section": "Search GOV.UK", "action": "search", "url": "/search/all" }' data-ga4-form-include-text="" data-module="ga4-form-tracker" id="search" method="get" role="search">
# <div class="gem-c-search govuk-!-display-none-print gem-c-search--large gem-c-search--on-white gem-c-search--separate-label" data-module="gem-toggle-input-class-on-focus">
# <label class="govuk-label govuk-label--m" for="search-main-107271b1">Search GOV.UK</label>
# <div class="gem-c-search__item-wrapper">
# <input class="gem-c-search__item gem-c-search__input js-class-toggle" enterkeyhint="search" id="search-main-107271b1" name="q" title="Search" type="search" value=""/>
# <div class="gem-c-search__item gem-c-search__submit-wrapper">
# <button class="gem-c-search__submit" data-module="gem-track-click" data-track-action="searchSubmitted" data-track-category="headerClicked" data-track-dimension="Search on GOV.UK" data-track-dimension-index="29" data-track-label="/search/all" enterkeyhint="search" type="submit">
#         Search
#
# <svg aria-hidden="true" class="gem-c-search__icon" fill="none" focusable="false" height="27" viewbox="0 0 27 27" width="27" xmlns="http://www.w3.org/2000/svg">
# <circle cx="12.0161" cy="11.0161" r="8.51613" stroke="currentColor" stroke-width="3"></circle>
# <line stroke="currentColor" stroke-width="3" x1="17.8668" x2="26.4475" y1="17.3587" y2="25.9393"></line>
# </svg>
# </button> </div>
# </div>
# </div>
# </form>
# </div>
# </div>
# <div class="govuk-grid-row">
# <div class="govuk-grid-column-full">
# <h3 class="govuk-heading-m">Popular on GOV.UK</h3>
# <ul class="govuk-list">
# <li class="gem-c-layout-super-navigation-header__popular-item">
# <a class="govuk-link gem-c-layout-super-navigation-header__popular-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":4,"index_link":1,"index_section_count":4},"index_total":5,"section":"Popular on GOV.UK"}' data-track-action="popularLink" data-track-category="headerClicked" data-track-dimension="Get support with the cost of living" data-track-dimension-index="29" data-track-label="/cost-of-living" href="/cost-of-living">Get support with the cost of living</a>
# </li>
# <li class="gem-c-layout-super-navigation-header__popular-item">
# <a class="govuk-link gem-c-layout-super-navigation-header__popular-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":4,"index_link":2,"index_section_count":4},"index_total":5,"section":"Popular on GOV.UK"}' data-track-action="popularLink" data-track-category="headerClicked" data-track-dimension="Find out about the Energy Bills Support Scheme" data-track-dimension-index="29" data-track-label="/guidance/getting-the-energy-bills-support-scheme-discount" href="/guidance/getting-the-energy-bills-support-scheme-discount">Find out about the Energy Bills Support Scheme</a>
# </li>
# <li class="gem-c-layout-super-navigation-header__popular-item">
# <a class="govuk-link gem-c-layout-super-navigation-header__popular-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":4,"index_link":3,"index_section_count":4},"index_total":5,"section":"Popular on GOV.UK"}' data-track-action="popularLink" data-track-category="headerClicked" data-track-dimension="Find a job" data-track-dimension-index="29" data-track-label="/find-a-job" href="/find-a-job">Find a job</a>
# </li>
# <li class="gem-c-layout-super-navigation-header__popular-item">
# <a class="govuk-link gem-c-layout-super-navigation-header__popular-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":4,"index_link":4,"index_section_count":4},"index_total":5,"section":"Popular on GOV.UK"}' data-track-action="popularLink" data-track-category="headerClicked" data-track-dimension="Universal Credit account: sign in" data-track-dimension-index="29" data-track-label="/sign-in-universal-credit" href="/sign-in-universal-credit">Universal Credit account: sign in</a>
# </li>
# <li class="gem-c-layout-super-navigation-header__popular-item">
# <a class="govuk-link gem-c-layout-super-navigation-header__popular-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":4,"index_link":5,"index_section_count":4},"index_total":5,"section":"Popular on GOV.UK"}' data-track-action="popularLink" data-track-category="headerClicked" data-track-dimension="Check your National Insurance record" data-track-dimension-index="29" data-track-label="/check-national-insurance-record" href="/check-national-insurance-record">Check your National Insurance record</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </nav>
# </div>
# </header>
# <div class="">
# <div class="gem-c-layout-for-public__blue-bar govuk-width-container"></div>
# </div>
# <div class="govuk-width-container" id="wrapper">
# <main class="finder-frontend-content" id="content">
# <div class="finder-frontend">
# <form action="/employment-tribunal-decisions" class="js-live-search-form" data-ga4-change-category="clear-all-filters" method="get">
# <input name="parent" type="hidden" value=""/>
# <div class="govuk-width-container">
# <div class="gem-c-phase-banner govuk-phase-banner">
# <p class="govuk-phase-banner__content">
# <strong class="govuk-tag govuk-phase-banner__content__tag">beta</strong>
# <span class="govuk-phase-banner__text">This part of GOV.UK is being rebuilt – <a class="govuk-link" href="/help/beta">find out what beta means</a></span>
# </p>
# </div>
# <div class="gem-c-contextual-breadcrumbs">
# <div class="gem-c-breadcrumbs govuk-breadcrumbs govuk-breadcrumbs--collapse-on-mobile" data-module="gem-track-click ga4-link-tracker">
# <ol class="govuk-breadcrumbs__list">
# <li class="govuk-breadcrumbs__list-item">
# <a class="govuk-breadcrumbs__link" data-ga4-link='{"event_name":"navigation","type":"breadcrumb","index":{"index_link":"1"},"index_total":"1"}' data-track-action="homeBreadcrumb" data-track-category="homeLinkClicked" data-track-label="" data-track-options="{}" href="/">Home</a>
# </li>
# </ol>
# </div>
# </div>
# <div class="govuk-grid-row">
# <div class="govuk-grid-column-two-thirds">
# <div class="gem-c-title govuk-!-margin-top-8 govuk-!-margin-bottom-8">
# <h1 class="gem-c-title__text govuk-heading-xl">
#     Employment tribunal decisions
#   </h1>
# </div>
# <div class="gem-c-metadata" data-module="gem-toggle metadata">
# <dl class="gem-c-metadata__list" data-module="gem-track-click">
# <dt class="gem-c-metadata__term">From:</dt>
# <dd class="gem-c-metadata__definition">
# <a href="https://www.gov.uk/government/organisations/hm-courts-and-tribunals-service">HM Courts &amp; Tribunals Service</a> and <a href="https://www.gov.uk/courts-tribunals/employment-tribunal">Employment Tribunal</a>
# </dd>
# </dl>
# </div>
# </div>
# <div class="govuk-grid-column-two-thirds">
# <div class="metadata-summary">
# <div class="gem-c-govspeak govuk-govspeak" data-module="govspeak">
# <p>Find decisions on Employment Tribunal cases in England, Wales and Scotland from February 2017 onwards.</p>
# <p>If the decision was made before February 2017 in England or Wales, Bury St Edmunds County Court might have it on record. Only the most requested decisions are currently available. Contact <a href="https://www.find-court-tribunal.service.gov.uk/courts/bury-st-edmunds-county-court-and-family-court">Bury St Edmunds County Court</a> to check.</p>
# <p>If the decision was made before February 2017 in Scotland, contact <a href="https://www.find-court-tribunal.service.gov.uk/courts/glasgow-tribunals-centre">Glasgow Tribunals Centre</a>.</p>
# <p>Decisions are not affected by GDPR rules and cannot be removed from GOV.UK.</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="govuk-width-container">
# <div class="govuk-grid-row">
# <div class="govuk-grid-column-one-third">
# <div class="filter-form">
# <div aria-label="Employment tribunal decisions" data-ga4-change-category="update-keyword text" id="keywords" role="search">
# <div class="gem-c-search govuk-!-display-none-print gem-c-search--on-white gem-c-search--separate-label" data-module="gem-toggle-input-class-on-focus">
# <label class="gem-c-search__label" for="finder-keyword-search">        Search <span class="govuk-visually-hidden">Employment tribunal decisions</span>
# </label>
# <div class="gem-c-search__item-wrapper">
# <input aria-controls="js-search-results-info" class="gem-c-search__item gem-c-search__input js-class-toggle" enterkeyhint="search" id="finder-keyword-search" name="keywords" title="Search" type="search" value=""/>
# <div class="gem-c-search__item gem-c-search__submit-wrapper">
# <button class="gem-c-search__submit" data-module="gem-track-click" enterkeyhint="search" type="submit">
#         Search
#
# <svg aria-hidden="true" class="gem-c-search__icon" fill="none" focusable="false" height="27" viewbox="0 0 27 27" width="27" xmlns="http://www.w3.org/2000/svg">
# <circle cx="12.0161" cy="11.0161" r="8.51613" stroke="currentColor" stroke-width="3"></circle>
# <line stroke="currentColor" stroke-width="3" x1="17.8668" x2="26.4475" y1="17.3587" y2="25.9393"></line>
# </svg>
# </button> </div>
# </div>
# </div>
# </div>
# <div class="app-c-mobile-filters">
# <button class="app-c-button-as-link app-mobile-filters-link js-toggle-mobile-filters" data-ga4-expandable="" data-module="ga4-event-tracker" data-target="facet-wrapper" data-toggle="mobile-filters-modal" data-track-action="mobile-filter-button" data-track-category="filterClicked" data-track-label="">
#       Filter <span class="govuk-visually-hidden"> results</span>
# <span class="js-selected-filter-count"></span>
# </button>
# <svg aria-hidden="true" class="mobile-filters-expander__icon mobile-filters-expander__icon--up" focusable="false" version="1.1" viewbox="0 0 1024 1024" xmlns="http://www.w3.org/2000/svg"><path d="m798.16 609.84l-256-256c-16.683-16.683-43.691-16.683-60.331 0l-256 256c-16.683 16.683-16.683 43.691 0 60.331s43.691 16.683 60.331 0l225.84-225.84 225.84 225.84c16.683 16.683 43.691 16.683 60.331 0s16.683-43.691 0-60.331z"></path></svg>
# <svg aria-hidden="true" class="mobile-filters-expander__icon mobile-filters-expander__icon--down" focusable="false" version="1.1" viewbox="0 0 1024 1024" xmlns="http://www.w3.org/2000/svg"><path d="m225.84 414.16l256 256c16.683 16.683 43.691 16.683 60.331 0l256-256c16.683-16.683 16.683-43.691 0-60.331s-43.691-16.683-60.331 0l-225.84 225.84-225.84-225.84c-16.683-16.683-43.691-16.683-60.331 0s-16.683 43.691 0 60.331z"></path></svg>
# </div>
# <div data-module="gem-track-click" data-track-action="skip-Link" data-track-category="filterClicked" data-track-label="">
# <a class="gem-c-skip-link govuk-skip-link govuk-!-display-none-print" data-module="govuk-skip-link" href="#js-results">Skip to results</a>
# </div>
# <div aria-label="Search filters" class="facets" data-module="mobile-filters-modal" id="facet-wrapper" role="search">
# <div class="facets__box">
# <h2 class="govuk-visually-hidden">Filter</h2>
# <div class="facets__header">
# <div>
# <h3 class="gem-c-heading govuk-heading-s govuk-!-margin-bottom-0">
# <span class="js-result-count govuk-!-font-weight-regular">103,723 decisions</span>
# </h3>
# </div>
# </div>
# <div class="facets__content" data-ga4-filter-container="" data-module="ga4-event-tracker">
# <div class="app-c-option-select" data-ga4-change-category="update-filter checkbox" data-ga4-section="Country" data-input-aria-controls="js-search-results-info" data-module="option-select">
# <h3 class="app-c-option-select__heading js-container-heading">
# <span class="app-c-option-select__title js-container-button" id="option-select-title-country">Country</span>
# <svg aria-hidden="true" class="app-c-option-select__icon app-c-option-select__icon--up" focusable="false" version="1.1" viewbox="0 0 1024 1024" xmlns="http://www.w3.org/2000/svg"><path d="m798.16 609.84l-256-256c-16.683-16.683-43.691-16.683-60.331 0l-256 256c-16.683 16.683-16.683 43.691 0 60.331s43.691 16.683 60.331 0l225.84-225.84 225.84 225.84c16.683 16.683 43.691 16.683 60.331 0s16.683-43.691 0-60.331z"></path></svg>
# <svg aria-hidden="true" class="app-c-option-select__icon app-c-option-select__icon--down" focusable="false" version="1.1" viewbox="0 0 1024 1024" xmlns="http://www.w3.org/2000/svg"><path d="m225.84 414.16l256 256c16.683 16.683 43.691 16.683 60.331 0l256-256c16.683-16.683 16.683-43.691 0-60.331s-43.691-16.683-60.331 0l-225.84 225.84-225.84-225.84c-16.683-16.683-43.691-16.683-60.331 0s-16.683 43.691 0 60.331z"></path></svg>
# </h3>
# <div aria-labelledby="option-select-title-country" class="app-c-option-select__container js-options-container" id="tribunal_decision_country" role="group" tabindex="-1">
# <div class="app-c-option-select__container-inner js-auto-height-inner">
# <div class="gem-c-checkboxes govuk-form-group govuk-checkboxes--small" data-module="gem-checkboxes govuk-checkboxes" id="checkboxes-e46ae254">
# <fieldset class="govuk-fieldset">
# <legend class="govuk-fieldset__legend govuk-fieldset__legend--m gem-c-checkboxes__legend--hidden">Country</legend>
# <ul class="govuk-checkboxes gem-c-checkboxes__list">
# <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Country" data-track-category="filterClicked" data-track-label="England and Wales" data-uncheck-track-category="filterRemoved" id="tribunal_decision_country-england-and-wales" name="tribunal_decision_country[]" type="checkbox" value="england-and-wales"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_country-england-and-wales">England and Wales</label>
# </li> <li class="govuk-checkboxes__item">
# <input class="govuk-checkboxes__input" data-controls="js-search-results-info" data-track-action="Country" data-track-category="filterClicked" data-track-label="Scotland" data-uncheck-track-category="filterRemoved" id="tribunal_decision_country-scotland" name="tribunal_decision_country[]" type="checkbox" value="scotland"/><label class="govuk-label govuk-checkboxes__label" for="tribunal_decision_country-scotland">Scotland</label>
# </li>
# </ul>
# </fieldset>
# </div>
# </div>
# </div>
# </div>
# <div class="app-c-option-select" data-closed-on-load="true" data-ga4-change-category="update-filter checkbox" data-ga4-section="Jurisdiction code" data-input-aria-controls="js-search-results-info" data-module="option-select">
# <h3 class="app-c-option-select__heading js-container-heading">
# <span class="app-c-option-select__title js-container-button" id="option-select-title-jurisdiction-code">Jurisdiction code</span>
# <svg aria-hidden="true" class="app-c-option-select__icon app-c-option-select__icon--up" focusable="false" version="1.1" viewbox="0 0 1024 1024" xmlns="http://www.w3.org/2000/svg"><path d="m798.16 609.84l-256-256c-16.683-16.683-43.691-16.683-60.331 0l-256 256c-16.683 16.683-16.683 43.691 0 60.331s43.691 16.683 60.331 0l225.84-225.84 225.84 225.84c16.683 16.683 43.691 16.683 60.331 0s16.683-43.691 0-60.331z"></path></svg>
# ...
# <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"10","index_section":"1","index_section_count":"5"},"index_total":"16","section":"Services and information"}' data-track-action="topicsLink" data-track-category="footerClicked" data-track-label="/browse/employing-people" data-track-options='{"dimension29":"Employing people"}' href="/browse/employing-people">Employing people</a>
# </li>
# <li class="govuk-footer__list-item">
# <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"11","index_section":"1","index_section_count":"5"},"index_total":"16","section":"Services and information"}' data-track-action="topicsLink" data-track-category="footerClicked" data-track-label="/browse/environment-countryside" data-track-options='{"dimension29":"Environment and countryside"}' href="/browse/environment-countryside">Environment and countryside</a>
# </li>
# <li class="govuk-footer__list-item">
# <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"12","index_section":"1","index_section_count":"5"},"index_total":"16","section":"Services and information"}' data-track-action="topicsLink" data-track-category="footerClicked" data-track-label="/browse/housing-local-services" data-track-options='{"dimension29":"Housing and local services"}' href="/browse/housing-local-services">Housing and local services</a>
# </li>
# <li class="govuk-footer__list-item">
# <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"13","index_section":"1","index_section_count":"5"},"index_total":"16","section":"Services and information"}' data-track-action="topicsLink" data-track-category="footerClicked" data-track-label="/browse/tax" data-track-options='{"dimension29":"Money and tax"}' href="/browse/tax">Money and tax</a>
# </li>
# <li class="govuk-footer__list-item">
# <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"14","index_section":"1","index_section_count":"5"},"index_total":"16","section":"Services and information"}' data-track-action="topicsLink" data-track-category="footerClicked" data-track-label="/browse/abroad" data-track-options='{"dimension29":"Passports, travel and living abroad"}' href="/browse/abroad">Passports, travel and living abroad</a>
# </li>
# <li class="govuk-footer__list-item">
# <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"15","index_section":"1","index_section_count":"5"},"index_total":"16","section":"Services and information"}' data-track-action="topicsLink" data-track-category="footerClicked" data-track-label="/browse/visas-immigration" data-track-options='{"dimension29":"Visas and immigration"}' href="/browse/visas-immigration">Visas and immigration</a>
# </li>
# <li class="govuk-footer__list-item">
# <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"16","index_section":"1","index_section_count":"5"},"index_total":"16","section":"Services and information"}' data-track-action="topicsLink" data-track-category="footerClicked" data-track-label="/browse/working" data-track-options='{"dimension29":"Working, jobs and pensions"}' href="/browse/working">Working, jobs and pensions</a>
# </li>
# </ul>
# </div>
# <div class="govuk-grid-column-one-third govuk-!-display-none-print">
# <h2 class="govuk-footer__heading govuk-heading-m">Government activity</h2>
# <ul class="govuk-footer__list govuk-footer__list--columns-1">
# <li class="govuk-footer__list-item">
# <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"1","index_section":"2","index_section_count":"5"},"index_total":"8","section":"Government activity"}' data-track-action="governmentactivityLink" data-track-category="footerClicked" data-track-label="/government/organisations" data-track-options='{"dimension29":"Departments"}' href="/government/organisations">Departments</a>
# </li>
# <li class="govuk-footer__list-item">
# <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"2","index_section":"2","index_section_count":"5"},"index_total":"8","section":"Government activity"}' data-track-action="governmentactivityLink" data-track-category="footerClicked" data-track-label="/search/news-and-communications" data-track-options='{"dimension29":"News"}' href="/search/news-and-communications">News</a>
# </li>
# <li class="govuk-footer__list-item">
# <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"3","index_section":"2","index_section_count":"5"},"index_total":"8","section":"Government activity"}' data-track-action="governmentactivityLink" data-track-category="footerClicked" data-track-label="/search/guidance-and-regulation" data-track-options='{"dimension29":"Guidance and regulation"}' href="/search/guidance-and-regulation">Guidance and regulation</a>
# </li>
# <li class="govuk-footer__list-item">
# <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"4","index_section":"2","index_section_count":"5"},"index_total":"8","section":"Government activity"}' data-track-action="governmentactivityLink" data-track-category="footerClicked" data-track-label="/search/research-and-statistics" data-track-options='{"dimension29":"Research and statistics"}' href="/search/research-and-statistics">Research and statistics</a>
# </li>
# <li class="govuk-footer__list-item">
# <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"5","index_section":"2","index_section_count":"5"},"index_total":"8","section":"Government activity"}' data-track-action="governmentactivityLink" data-track-category="footerClicked" data-track-label="/search/policy-papers-and-consultations" data-track-options='{"dimension29":"Policy papers and consultations"}' href="/search/policy-papers-and-consultations">Policy papers and consultations</a>
# </li>
# <li class="govuk-footer__list-item">
# <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"6","index_section":"2","index_section_count":"5"},"index_total":"8","section":"Government activity"}' data-track-action="governmentactivityLink" data-track-category="footerClicked" data-track-label="/search/transparency-and-freedom-of-information-releases" data-track-options='{"dimension29":"Transparency"}' href="/search/transparency-and-freedom-of-information-releases">Transparency</a>
# </li>
# <li class="govuk-footer__list-item">
# <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"7","index_section":"2","index_section_count":"5"},"index_total":"8","section":"Government activity"}' data-track-action="governmentactivityLink" data-track-category="footerClicked" data-track-label="/government/how-government-works" data-track-options='{"dimension29":"How government works"}' href="/government/how-government-works">How government works</a>
# </li>
# <li class="govuk-footer__list-item">
# <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"8","index_section":"2","index_section_count":"5"},"index_total":"8","section":"Government activity"}' data-track-action="governmentactivityLink" data-track-category="footerClicked" data-track-label="/government/get-involved" data-track-options='{"dimension29":"Get involved"}' href="/government/get-involved">Get involved</a>
# </li>
# </ul>
# </div>
# </div>
# <hr class="govuk-footer__section-break"/>
# <div class="govuk-footer__meta">
# <div class="govuk-footer__meta-item govuk-footer__meta-item--grow">
# <h2 class="govuk-visually-hidden">Support links</h2>
# <ul class="govuk-footer__inline-list govuk-!-display-none-print" data-module="gem-track-click" data-track-links-only="">
# <li class="govuk-footer__inline-list-item">
# <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"1","index_section":"3","index_section_count":"5"},"index_total":"8","section":"Support links"}' data-track-action="supportLink" data-track-category="footerClicked" data-track-label="/help" data-track-options='{"dimension29":"Help"}' href="/help">Help</a>
# </li>
# <li class="govuk-footer__inline-list-item">
# <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"2","index_section":"3","index_section_count":"5"},"index_total":"8","section":"Support links"}' data-track-action="supportLink" data-track-category="footerClicked" data-track-label="/help/privacy-notice" data-track-options='{"dimension29":"Privacy"}' href="/help/privacy-notice">Privacy</a>
# </li>
# <li class="govuk-footer__inline-list-item">
# <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"3","index_section":"3","index_section_count":"5"},"index_total":"8","section":"Support links"}' data-track-action="supportLink" data-track-category="footerClicked" data-track-label="/help/cookies" data-track-options='{"dimension29":"Cookies"}' href="/help/cookies">Cookies</a>
# </li>
# <li class="govuk-footer__inline-list-item">
# <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"4","index_section":"3","index_section_count":"5"},"index_total":"8","section":"Support links"}' data-track-action="supportLink" data-track-category="footerClicked" data-track-label="/help/accessibility-statement" data-track-options='{"dimension29":"Accessibility statement"}' href="/help/accessibility-statement">Accessibility statement</a>
# </li>
# <li class="govuk-footer__inline-list-item">
# <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"5","index_section":"3","index_section_count":"5"},"index_total":"8","section":"Support links"}' data-track-action="supportLink" data-track-category="footerClicked" data-track-label="/contact" data-track-options='{"dimension29":"Contact"}' href="/contact">Contact</a>
# </li>
# <li class="govuk-footer__inline-list-item">
# <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"6","index_section":"3","index_section_count":"5"},"index_total":"8","section":"Support links"}' data-track-action="supportLink" data-track-category="footerClicked" data-track-label="/help/terms-conditions" data-track-options='{"dimension29":"Terms and conditions"}' href="/help/terms-conditions">Terms and conditions</a>
# </li>
# <li class="govuk-footer__inline-list-item">
# <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"7","index_section":"3","index_section_count":"5"},"index_total":"8","section":"Support links"}' data-track-action="supportLink" data-track-category="footerClicked" data-track-label="/cymraeg" data-track-options='{"dimension29":"Rhestr o Wasanaethau Cymraeg"}' href="/cymraeg" lang="cy">Rhestr o Wasanaethau Cymraeg</a>
# </li>
# <li class="govuk-footer__inline-list-item">
# <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"8","index_section":"3","index_section_count":"5"},"index_total":"8","section":"Support links"}' data-track-action="supportLink" data-track-category="footerClicked" data-track-label="/government/organisations/government-digital-service" data-track-options='{"dimension29":"Government Digital Service"}' href="/government/organisations/government-digital-service">Government Digital Service</a>
# </li>
# </ul>
# <svg aria-hidden="true" class="govuk-footer__licence-logo" focusable="false" height="17" viewbox="0 0 483.2 195.7" width="41" xmlns="http://www.w3.org/2000/svg">
# <path d="M421.5 142.8V.1l-50.7 32.3v161.1h112.4v-50.7zm-122.3-9.6A47.12 47.12 0 0 1 221 97.8c0-26 21.1-47.1 47.1-47.1 16.7 0 31.4 8.7 39.7 21.8l42.7-27.2A97.63 97.63 0 0 0 268.1 0c-36.5 0-68.3 20.1-85.1 49.7A98 98 0 0 0 97.8 0C43.9 0 0 43.9 0 97.8s43.9 97.8 97.8 97.8c36.5 0 68.3-20.1 85.1-49.7a97.76 97.76 0 0 0 149.6 25.4l19.4 22.2h3v-87.8h-80l24.3 27.5zM97.8 145c-26 0-47.1-21.1-47.1-47.1s21.1-47.1 47.1-47.1 47.2 21 47.2 47S123.8 145 97.8 145" fill="currentColor"></path>
# </svg>
# <span class="govuk-footer__licence-description" data-ga4-link='{"event_name":"navigation","section":"Licence","index":{"index_section":"4","index_link":"1","index_section_count":"5"},"text":"Open Government Licence v3.0","index_total":"1","type":"footer"}' data-ga4-track-links-only="" data-module="gem-track-click" data-track-action="copyrightLink" data-track-category="footerClicked" data-track-label="https://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/" data-track-links-only="" data-track-options='{"dimension29": "Open Government Licence v3.0"}'>
#           All content is available under the <a class="govuk-footer__link" href="https://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/" rel="license">Open Government Licence v3.0</a>, except where otherwise stated
#         </span>
# </div>
# <div class="govuk-footer__meta-item" data-ga4-link='{"event_name":"navigation","section":"Copyright","index":{"index_section":"5","index_link":"1","index_section_count":"5"},"text":"© Crown copyright","index_total":"1","type":"footer"}' data-module="gem-track-click" data-track-action="copyrightLink" data-track-category="footerClicked" data-track-label="https://www.nationalarchives.gov.uk/information-management/re-using-public-sector-information/uk-government-licensing-framework/crown-copyright/" data-track-links-only="" data-track-options='{"dimension29": "© Crown copyright"}'>
# <a class="govuk-footer__link govuk-footer__copyright-logo" href="https://www.nationalarchives.gov.uk/information-management/re-using-public-sector-information/uk-government-licensing-framework/crown-copyright/">© Crown copyright</a>
# </div>
# </div>
# </div>
# </footer>
# <script src="/assets/static/application-6baac002cbe9dba75d166b11906536d1aeb4f61ec5c838f05250dcc751b2c578.js"></script>
# <script src="/assets/finder-frontend/application-7cd39ed03971c337178f2287aa5086474ace8c0ab7c36229f4d8732c70471283.js"></script><script type="application/ld+json">
#   {
#   "@context": "http://schema.org",
#   "@type": "SearchResultsPage",
#   "mainEntityOfPage": {
#     "@type": "WebPage",
#     "@id": "https://www.gov.uk/employment-tribunal-decisions"
#   },
#   "name": "Employment tribunal decisions",
#   "datePublished": "2017-02-08T16:15:17Z",
#   "dateModified": "2023-02-07T11:26:26Z",
#   "text": "Find decisions on Employment Tribunal cases in England, Wales and Scotland.",
#   "publisher": {
#     "@type": "Organization",
#     "name": "GOV.UK",
#     "url": "https://www.gov.uk",
#     "logo": {
#       "@type": "ImageObject",
#       "url": "https://www.gov.uk/assets/finder-frontend/govuk_publishing_components/govuk-logo-73b5a4056ffe9988d02c728b56fe9fe7f90bb822322a5f6183ccbb92a99b019a.png"
#     }
#   },
#   "image": [
#     "https://www.gov.uk/assets/finder-frontend/govuk_publishing_components/govuk-schema-placeholder-1x1-bf9e64d759af6dfd93bede8168f3087a329f405b382aff36747db0db4b7b23e9.png",
#     "https://www.gov.uk/assets/finder-frontend/govuk_publishing_components/govuk-schema-placeholder-4x3-13093f053c15f613acd827aff27cac83d3fab452947cbcae4c7b706dadf2f7f2.png",
#     "https://www.gov.uk/assets/finder-frontend/govuk_publishing_components/govuk-schema-placeholder-16x9-4233cd42671827e266e284c4d5ae68fb600bd9f9e35dda663ccabbc2b6ab7ec3.png"
#   ]
# }
# </script><script type="application/ld+json">
#   {
#   "@context": "http://schema.org",
#   "@type": "BreadcrumbList",
#   "itemListElement": [
#     {
#       "@type": "ListItem",
#       "position": 1,
#       "item": {
#         "name": "Home",
#         "@id": "https://www.gov.uk/"
#       }
#     }
#   ]
# }
# </script>
# </body>
# </html>

# %% [markdown]
# ## Grabbing all the link text
#
# We check we can grab the text which is linked to each case. To do this we add `.select()` to the `soup` object, and specify a **selector** inside the brackets.
#
# To grab all the links on the page we would target the `<a>` tag. The selector for that is simply `'a'`.

# %%
#select all the <a> tags inside the soup object (the webpage)
#because we are not storing this inside a variable it will simply display the results
soup.select('a')
# Out:
# [<a class="gem-c-skip-link govuk-skip-link govuk-!-display-none-print" data-module="govuk-skip-link" href="#content">Skip to main content</a>,
#  <a class="govuk-link" data-module="gem-track-click" data-track-action="Cookie banner settings clicked from confirmation" data-track-category="cookieBanner" href="/help/cookies">change your cookie settings</a>,
#  <a class="govuk-link" data-module="gem-track-click" data-track-action="Cookie banner settings clicked from confirmation" data-track-category="cookieBanner" href="/help/cookies">change your cookie settings</a>,
#  <a class="govuk-link" href="/help/cookies">View cookies</a>,
#  <a class="govuk-header__link govuk-header__link--homepage" data-ga4-link='{"event_name":"navigation","type":"header menu bar","external":"false","text":"GOV.UK","section":"Logo","index":{"index_link":1,"index_section":0,"index_section_count":2},"index_total":1}' data-track-action="logoLink" data-track-category="headerClicked" data-track-dimension="GOV.UK" data-track-dimension-index="29" data-track-label="https://www.gov.uk" href="https://www.gov.uk" id="logo" title="Go to the GOV.UK homepage">
#  <span class="govuk-header__logotype">
#  <!--[if gt IE 8]><!-->
#  <svg aria-hidden="true" class="govuk-header__logotype-crown gem-c-layout-super-navigation-header__logotype-crown" focusable="false" height="30" viewbox="0 0 132 97" width="36" xmlns="http://www.w3.org/2000/svg">
#  <path d="M25 30.2c3.5 1.5 7.7-.2 9.1-3.7 1.5-3.6-.2-7.8-3.9-9.2-3.6-1.4-7.6.3-9.1 3.9-1.4 3.5.3 7.5 3.9 9zM9 39.5c3.6 1.5 7.8-.2 9.2-3.7 1.5-3.6-.2-7.8-3.9-9.1-3.6-1.5-7.6.2-9.1 3.8-1.4 3.5.3 7.5 3.8 9zM4.4 57.2c3.5 1.5 7.7-.2 9.1-3.8 1.5-3.6-.2-7.7-3.9-9.1-3.5-1.5-7.6.3-9.1 3.8-1.4 3.5.3 7.6 3.9 9.1zm38.3-21.4c3.5 1.5 7.7-.2 9.1-3.8 1.5-3.6-.2-7.7-3.9-9.1-3.6-1.5-7.6.3-9.1 3.8-1.3 3.6.4 7.7 3.9 9.1zm64.4-5.6c-3.6 1.5-7.8-.2-9.1-3.7-1.5-3.6.2-7.8 3.8-9.2 3.6-1.4 7.7.3 9.2 3.9 1.3 3.5-.4 7.5-3.9 9zm15.9 9.3c-3.6 1.5-7.7-.2-9.1-3.7-1.5-3.6.2-7.8 3.7-9.1 3.6-1.5 7.7.2 9.2 3.8 1.5 3.5-.3 7.5-3.8 9zm4.7 17.7c-3.6 1.5-7.8-.2-9.2-3.8-1.5-3.6.2-7.7 3.9-9.1 3.6-1.5 7.7.3 9.2 3.8 1.3 3.5-.4 7.6-3.9 9.1zM89.3 35.8c-3.6 1.5-7.8-.2-9.2-3.8-1.4-3.6.2-7.7 3.9-9.1 3.6-1.5 7.7.3 9.2 3.8 1.4 3.6-.3 7.7-3.9 9.1zM69.7 17.7l8.9 4.7V9.3l-8.9 2.8c-.2-.3-.5-.6-.9-.9L72.4 0H59.6l3.5 11.2c-.3.3-.6.5-.9.9l-8.8-2.8v13.1l8.8-4.7c.3.3.6.7.9.9l-5 15.4v.1c-.2.8-.4 1.6-.4 2.4 0 4.1 3.1 7.5 7 8.1h.2c.3 0 .7.1 1 .1.4 0 .7 0 1-.1h.2c4-.6 7.1-4.1 7.1-8.1 0-.8-.1-1.7-.4-2.4V34l-5.1-15.4c.4-.2.7-.6 1-.9zM66 92.8c16.9 0 32.8 1.1 47.1 3.2 4-16.9 8.9-26.7 14-33.5l-9.6-3.4c1 4.9 1.1 7.2 0 10.2-1.5-1.4-3-4.3-4.2-8.7L108.6 76c2.8-2 5-3.2 7.5-3.3-4.4 9.4-10 11.9-13.6 11.2-4.3-.8-6.3-4.6-5.6-7.9 1-4.7 5.7-5.9 8-.5 4.3-8.7-3-11.4-7.6-8.8 7.1-7.2 7.9-13.5 2.1-21.1-8 6.1-8.1 12.3-4.5 20.8-4.7-5.4-12.1-2.5-9.5 6.2 3.4-5.2 7.9-2 7.2 3.1-.6 4.3-6.4 7.8-13.5 7.2-10.3-.9-10.9-8-11.2-13.8 2.5-.5 7.1 1.8 11 7.3L80.2 60c-4.1 4.4-8 5.3-12.3 5.4 1.4-4.4 8-11.6 8-11.6H55.5s6.4 7.2 7.9 11.6c-4.2-.1-8-1-12.3-5.4l1.4 16.4c3.9-5.5 8.5-7.7 10.9-7.3-.3 5.8-.9 12.8-11.1 13.8-7.2.6-12.9-2.9-13.5-7.2-.7-5 3.8-8.3 7.1-3.1 2.7-8.7-4.6-11.6-9.4-6.2 3.7-8.5 3.6-14.7-4.6-20.8-5.8 7.6-5 13.9 2.2 21.1-4.7-2.6-11.9.1-7.7 8.8 2.3-5.5 7.1-4.2 8.1.5.7 3.3-1.3 7.1-5.7 7.9-3.5.7-9-1.8-13.5-11.2 2.5.1 4.7 1.3 7.5 3.3l-4.7-15.4c-1.2 4.4-2.7 7.2-4.3 8.7-1.1-3-.9-5.3 0-10.2l-9.5 3.4c5 6.9 9.9 16.7 14 33.5 14.8-2.1 30.8-3.2 47.7-3.2z" fill="currentColor" fill-rule="evenodd">
#  </path>
#  </svg>
#  <!--<![endif]-->
#  <!--[if IE 8]>
#              <img src="/assets/static/govuk-logotype-crown-66ad9a9b8fca42cf0ba18979eef6afc2e8056d5f158ca9b27ce9afdf852aae87.png" alt="" class="govuk-header__logotype-crown-fallback-image" width="36" height="32">
#              <![endif]-->
#  <span class="govuk-header__logotype-text">
#                GOV.UK
#              </span>
#  </span>
#  </a>,
#  <a class="gem-c-layout-super-navigation-header__navigation-item-link" data-track-action="menuLink" data-track-category="headerClicked" data-track-dimension="Menu" data-track-dimension-index="29" data-track-label="/browse" href="/browse">
#  <span class="gem-c-layout-super-navigation-header__navigation-item-link-inner">
#                  Menu
#                </span>
#  </a>,
#  <a class="gem-c-layout-super-navigation-header__search-item-link" href="/search">
#  <span class="govuk-visually-hidden">
#                  Search GOV.UK
#                </span>
#  <svg aria-hidden="true" class="gem-c-layout-super-navigation-header__search-item-link-icon" fill="none" focusable="false" height="27" viewbox="0 0 27 27" width="27" xmlns="http://www.w3.org/2000/svg">
#  <circle cx="12.0161" cy="11.0161" r="8.51613" stroke="currentColor" stroke-width="3"></circle>
#  <line stroke="currentColor" stroke-width="3" x1="17.8668" x2="26.4475" y1="17.3587" y2="25.9393"></line>
#  </svg>
#  </a>,
#  <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":1,"index_link":1,"index_section_count":4},"index_total":16,"section":"Services and information"}' data-track-action="servicesandinformationLink" data-track-category="headerClicked" data-track-dimension="Benefits" data-track-dimension-index="29" data-track-label="/browse/benefits" href="/browse/benefits">Benefits</a>,
#  <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":1,"index_link":2,"index_section_count":4},"index_total":16,"section":"Services and information"}' data-track-action="servicesandinformationLink" data-track-category="headerClicked" data-track-dimension="Births, death, marriages and care" data-track-dimension-index="29" data-track-label="/browse/births-deaths-marriages" href="/browse/births-deaths-marriages">Births, death, marriages and care</a>,
#  <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":1,"index_link":3,"index_section_count":4},"index_total":16,"section":"Services and information"}' data-track-action="servicesandinformationLink" data-track-category="headerClicked" data-track-dimension="Business and self-employed" data-track-dimension-index="29" data-track-label="/browse/business" href="/browse/business">Business and self-employed</a>,
#  <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":1,"index_link":4,"index_section_count":4},"index_total":16,"section":"Services and information"}' data-track-action="servicesandinformationLink" data-track-category="headerClicked" data-track-dimension="Childcare and parenting" data-track-dimension-index="29" data-track-label="/browse/childcare-parenting" href="/browse/childcare-parenting">Childcare and parenting</a>,
#  <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":1,"index_link":5,"index_section_count":4},"index_total":16,"section":"Services and information"}' data-track-action="servicesandinformationLink" data-track-category="headerClicked" data-track-dimension="Citizenship and living in the UK" data-track-dimension-index="29" data-track-label="/browse/citizenship" href="/browse/citizenship">Citizenship and living in the UK</a>,
#  <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":1,"index_link":6,"index_section_count":4},"index_total":16,"section":"Services and information"}' data-track-action="servicesandinformationLink" data-track-category="headerClicked" data-track-dimension="Crime, justice and the law" data-track-dimension-index="29" data-track-label="/browse/justice" href="/browse/justice">Crime, justice and the law</a>,
#  <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":1,"index_link":7,"index_section_count":4},"index_total":16,"section":"Services and information"}' data-track-action="servicesandinformationLink" data-track-category="headerClicked" data-track-dimension="Disabled people" data-track-dimension-index="29" data-track-label="/browse/disabilities" href="/browse/disabilities">Disabled people</a>,
#  <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":1,"index_link":8,"index_section_count":4},"index_total":16,"section":"Services and information"}' data-track-action="servicesandinformationLink" data-track-category="headerClicked" data-track-dimension="Driving and transport" data-track-dimension-index="29" data-track-label="/browse/driving" href="/browse/driving">Driving and transport</a>,
#  <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":1,"index_link":9,"index_section_count":4},"index_total":16,"section":"Services and information"}' data-track-action="servicesandinformationLink" data-track-category="headerClicked" data-track-dimension="Education and learning" data-track-dimension-index="29" data-track-label="/browse/education" href="/browse/education">Education and learning</a>,
#  <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":1,"index_link":10,"index_section_count":4},"index_total":16,"section":"Services and information"}' data-track-action="servicesandinformationLink" data-track-category="headerClicked" data-track-dimension="Employing people" data-track-dimension-index="29" data-track-label="/browse/employing-people" href="/browse/employing-people">Employing people</a>,
#  <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":1,"index_link":11,"index_section_count":4},"index_total":16,"section":"Services and information"}' data-track-action="servicesandinformationLink" data-track-category="headerClicked" data-track-dimension="Environment and countryside" data-track-dimension-index="29" data-track-label="/browse/environment-countryside" href="/browse/environment-countryside">Environment and countryside</a>,
#  <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":1,"index_link":12,"index_section_count":4},"index_total":16,"section":"Services and information"}' data-track-action="servicesandinformationLink" data-track-category="headerClicked" data-track-dimension="Housing and local services" data-track-dimension-index="29" data-track-label="/browse/housing-local-services" href="/browse/housing-local-services">Housing and local services</a>,
#  <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":1,"index_link":13,"index_section_count":4},"index_total":16,"section":"Services and information"}' data-track-action="servicesandinformationLink" data-track-category="headerClicked" data-track-dimension="Money and tax" data-track-dimension-index="29" data-track-label="/browse/tax" href="/browse/tax">Money and tax</a>,
#  <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":1,"index_link":14,"index_section_count":4},"index_total":16,"section":"Services and information"}' data-track-action="servicesandinformationLink" data-track-category="headerClicked" data-track-dimension="Passports, travel and living abroad" data-track-dimension-index="29" data-track-label="/browse/abroad" href="/browse/abroad">Passports, travel and living abroad</a>,
#  <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":1,"index_link":15,"index_section_count":4},"index_total":16,"section":"Services and information"}' data-track-action="servicesandinformationLink" data-track-category="headerClicked" data-track-dimension="Visas and immigration" data-track-dimension-index="29" data-track-label="/browse/visas-immigration" href="/browse/visas-immigration">Visas and immigration</a>,
#  <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":1,"index_link":16,"index_section_count":4},"index_total":16,"section":"Services and information"}' data-track-action="servicesandinformationLink" data-track-category="headerClicked" data-track-dimension="Working, jobs and pensions" data-track-dimension-index="29" data-track-label="/browse/working" href="/browse/working">Working, jobs and pensions</a>,
#  <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link gem-c-layout-super-navigation-header__navigation-second-item-link--with-description" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":2,"index_link":1,"index_section_count":4},"index_total":6,"section":"Government activity"}' data-track-action="governmentactivityLink" data-track-category="headerClicked" data-track-dimension="Departments" data-track-dimension-index="29" data-track-label="/government/organisations" href="/government/organisations">Departments</a>,
#  <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link gem-c-layout-super-navigation-header__navigation-second-item-link--with-description" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":2,"index_link":2,"index_section_count":4},"index_total":6,"section":"Government activity"}' data-track-action="governmentactivityLink" data-track-category="headerClicked" data-track-dimension="News" data-track-dimension-index="29" data-track-label="/search/news-and-communications" href="/search/news-and-communications">News</a>,
#  <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link gem-c-layout-super-navigation-header__navigation-second-item-link--with-description" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":2,"index_link":3,"index_section_count":4},"index_total":6,"section":"Government activity"}' data-track-action="governmentactivityLink" data-track-category="headerClicked" data-track-dimension="Guidance and regulation" data-track-dimension-index="29" data-track-label="/search/guidance-and-regulation" href="/search/guidance-and-regulation">Guidance and regulation</a>,
#  <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link gem-c-layout-super-navigation-header__navigation-second-item-link--with-description" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":2,"index_link":4,"index_section_count":4},"index_total":6,"section":"Government activity"}' data-track-action="governmentactivityLink" data-track-category="headerClicked" data-track-dimension="Research and statistics" data-track-dimension-index="29" data-track-label="/search/research-and-statistics" href="/search/research-and-statistics">Research and statistics</a>,
#  <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link gem-c-layout-super-navigation-header__navigation-second-item-link--with-description" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":2,"index_link":5,"index_section_count":4},"index_total":6,"section":"Government activity"}' data-track-action="governmentactivityLink" data-track-category="headerClicked" data-track-dimension="Policy papers and consultations" data-track-dimension-index="29" data-track-label="/search/policy-papers-and-consultations" href="/search/policy-papers-and-consultations">Policy papers and consultations</a>,
#  <a class="govuk-link gem-c-layout-super-navigation-header__navigation-second-item-link gem-c-layout-super-navigation-header__navigation-second-item-link--with-description" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":2,"index_link":6,"index_section_count":4},"index_total":6,"section":"Government activity"}' data-track-action="governmentactivityLink" data-track-category="headerClicked" data-track-dimension="Transparency" data-track-dimension-index="29" data-track-label="/search/transparency-and-freedom-of-information-releases" href="/search/transparency-and-freedom-of-information-releases">Transparency</a>,
#  <a class="govuk-link gem-c-layout-super-navigation-header__popular-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":4,"index_link":1,"index_section_count":4},"index_total":5,"section":"Popular on GOV.UK"}' data-track-action="popularLink" data-track-category="headerClicked" data-track-dimension="Get support with the cost of living" data-track-dimension-index="29" data-track-label="/cost-of-living" href="/cost-of-living">Get support with the cost of living</a>,
#  <a class="govuk-link gem-c-layout-super-navigation-header__popular-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":4,"index_link":2,"index_section_count":4},"index_total":5,"section":"Popular on GOV.UK"}' data-track-action="popularLink" data-track-category="headerClicked" data-track-dimension="Find out about the Energy Bills Support Scheme" data-track-dimension-index="29" data-track-label="/guidance/getting-the-energy-bills-support-scheme-discount" href="/guidance/getting-the-energy-bills-support-scheme-discount">Find out about the Energy Bills Support Scheme</a>,
#  <a class="govuk-link gem-c-layout-super-navigation-header__popular-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":4,"index_link":3,"index_section_count":4},"index_total":5,"section":"Popular on GOV.UK"}' data-track-action="popularLink" data-track-category="headerClicked" data-track-dimension="Find a job" data-track-dimension-index="29" data-track-label="/find-a-job" href="/find-a-job">Find a job</a>,
#  <a class="govuk-link gem-c-layout-super-navigation-header__popular-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":4,"index_link":4,"index_section_count":4},"index_total":5,"section":"Popular on GOV.UK"}' data-track-action="popularLink" data-track-category="headerClicked" data-track-dimension="Universal Credit account: sign in" data-track-dimension-index="29" data-track-label="/sign-in-universal-credit" href="/sign-in-universal-credit">Universal Credit account: sign in</a>,
#  <a class="govuk-link gem-c-layout-super-navigation-header__popular-link" data-ga4-link='{"event_name":"navigation","type":"header menu bar","index":{"index_section":4,"index_link":5,"index_section_count":4},"index_total":5,"section":"Popular on GOV.UK"}' data-track-action="popularLink" data-track-category="headerClicked" data-track-dimension="Check your National Insurance record" data-track-dimension-index="29" data-track-label="/check-national-insurance-record" href="/check-national-insurance-record">Check your National Insurance record</a>,
#  <a class="govuk-link" href="/help/beta">find out what beta means</a>,
#  <a class="govuk-breadcrumbs__link" data-ga4-link='{"event_name":"navigation","type":"breadcrumb","index":{"index_link":"1"},"index_total":"1"}' data-track-action="homeBreadcrumb" data-track-category="homeLinkClicked" data-track-label="" data-track-options="{}" href="/">Home</a>,
#  <a href="https://www.gov.uk/government/organisations/hm-courts-and-tribunals-service">HM Courts &amp; Tribunals Service</a>,
#  <a href="https://www.gov.uk/courts-tribunals/employment-tribunal">Employment Tribunal</a>,
#  <a href="https://www.find-court-tribunal.service.gov.uk/courts/bury-st-edmunds-county-court-and-family-court">Bury St Edmunds County Court</a>,
#  <a href="https://www.find-court-tribunal.service.gov.uk/courts/glasgow-tribunals-centre">Glasgow Tribunals Centre</a>,
#  <a class="gem-c-skip-link govuk-skip-link govuk-!-display-none-print" data-module="govuk-skip-link" href="#js-results">Skip to results</a>,
#  <a class="gem-c-button govuk-button" data-module="govuk-button govuk-skip-link" draggable="false" href="#js-results" role="button">Go to search results</a>,
#  <a class="gem-c-skip-link govuk-skip-link govuk-!-display-none-print" data-module="govuk-skip-link" href="#js-results">Skip to results</a>,
#  <a class="govuk-link gem-c-subscription-links__item gem-c-subscription-links__item--link" href="/employment-tribunal-decisions/email-signup"> <svg aria-hidden="true" class="gem-c-subscription-links__icon" fill="currentColor" focusable="false" height="15.75" width="21" xmlns="http://www.w3.org/2000/svg"><path d="M19.687 0H1.312C.589 0 0 .587 0 1.313v13.124c0 .726.588 1.313 1.313 1.313h18.374c.725 0 1.313-.587 1.313-1.313V1.313C21 .587 20.412 0 19.687 0zm-2.625 2.625L10.5 7.875l-6.563-5.25h13.126zm1.313 10.5H2.625V3.937L10.5 10.5l7.875-6.563v9.188z"></path>
#  </svg>Get emails
#  </a>,
#  <a class="govuk-link govuk-link--no-underline gem-c-subscription-links__item gem-c-subscription-links__item--link" href="/employment-tribunal-decisions.atom"> <svg aria-hidden="true" class="gem-c-subscription-links__icon" fill="currentColor" focusable="false" height="15" width="15" xmlns="http://www.w3.org/2000/svg"><path d="M1.996 11A2 2 0 0 0 0 12.993c0 1.101.895 1.99 1.996 1.99 1.106 0 2-.889 2-1.99a2 2 0 0 0-2-1.993zM.002 5.097V7.97c1.872 0 3.632.733 4.958 2.059A6.984 6.984 0 0 1 7.015 15h2.888c0-5.461-4.443-9.903-9.9-9.903zM.006 0v2.876c6.676 0 12.11 5.44 12.11 12.124H15C15 6.731 8.273 0 .006 0z"></path>
#  </svg>Subscribe to feed
#  </a>,
#  <a class="govuk-link" data-ecommerce-index="1" data-ecommerce-path="/employment-tribunal-decisions/ms-i-m-de-araujo-ramos-fernandes-v-eden-brook-home-care-ltd-3205112-slash-2022" data-ecommerce-row="1" data-ga4-ecommerce-path="/employment-tribunal-decisions/ms-i-m-de-araujo-ramos-fernandes-v-eden-brook-home-care-ltd-3205112-slash-2022" data-track-action="Employment tribunal decisions.1" data-track-category="navFinderLinkClicked" data-track-label="/employment-tribunal-decisions/ms-i-m-de-araujo-ramos-fernandes-v-eden-brook-home-care-ltd-3205112-slash-2022" data-track-options='{"dimension28":50,"dimension29":"Ms I M de Araújo Ramos Fernandes v Eden Brook Home Care Ltd: 3205112/2022"}' href="/employment-tribunal-decisions/ms-i-m-de-araujo-ramos-fernandes-v-eden-brook-home-care-ltd-3205112-slash-2022">Ms I M de Araújo Ramos Fernandes v Eden Brook Home Care Ltd: 3205112/2022</a>,
#  <a class="govuk-link" data-ecommerce-index="2" data-ecommerce-path="/employment-tribunal-decisions/mrs-p-marques-v-just-kidd-inn-ltd-3200680-slash-2023" data-ecommerce-row="1" data-ga4-ecommerce-path="/employment-tribunal-decisions/mrs-p-marques-v-just-kidd-inn-ltd-3200680-slash-2023" data-track-action="Employment tribunal decisions.2" data-track-category="navFinderLinkClicked" data-track-label="/employment-tribunal-decisions/mrs-p-marques-v-just-kidd-inn-ltd-3200680-slash-2023" data-track-options='{"dimension28":50,"dimension29":"Mrs P Marques v Just Kidd Inn Ltd: 3200680/2023"}' href="/employment-tribunal-decisions/mrs-p-marques-v-just-kidd-inn-ltd-3200680-slash-2023">Mrs P Marques v Just Kidd Inn Ltd: 3200680/2023</a>,
#  <a class="govuk-link" data-ecommerce-index="3" data-ecommerce-path="/employment-tribunal-decisions/mrs-k-janusz-v-abc-distribution-ltd-3200710-slash-2023" data-ecommerce-row="1" data-ga4-ecommerce-path="/employment-tribunal-decisions/mrs-k-janusz-v-abc-distribution-ltd-3200710-slash-2023" data-track-action="Employment tribunal decisions.3" data-track-category="navFinderLinkClicked" data-track-label="/employment-tribunal-decisions/mrs-k-janusz-v-abc-distribution-ltd-3200710-slash-2023" data-track-options='{"dimension28":50,"dimension29":"Mrs K Janusz v ABC Distribution Ltd: 3200710/2023"}' href="/employment-tribunal-decisions/mrs-k-janusz-v-abc-distribution-ltd-3200710-slash-2023">Mrs K Janusz v ABC Distribution Ltd: 3200710/2023</a>,
#  <a class="govuk-link" data-ecommerce-index="4" data-ecommerce-path="/employment-tribunal-decisions/mr-d-singh-v-wanis-management-services-llp-3200018-slash-2023" data-ecommerce-row="1" data-ga4-ecommerce-path="/employment-tribunal-decisions/mr-d-singh-v-wanis-management-services-llp-3200018-slash-2023" data-track-action="Employment tribunal decisions.4" data-track-category="navFinderLinkClicked" data-track-label="/employment-tribunal-decisions/mr-d-singh-v-wanis-management-services-llp-3200018-slash-2023" data-track-options='{"dimension28":50,"dimension29":"Mr D Singh v Wanis Management Services LLP: 3200018/2023"}' href="/employment-tribunal-decisions/mr-d-singh-v-wanis-management-services-llp-3200018-slash-2023">Mr D Singh v Wanis Management Services LLP: 3200018/2023</a>,
#  <a class="govuk-link" data-ecommerce-index="5" data-ecommerce-path="/employment-tribunal-decisions/mr-a-sesay-v-bardwood-support-services-ltd-3205655-slash-2022" data-ecommerce-row="1" data-ga4-ecommerce-path="/employment-tribunal-decisions/mr-a-sesay-v-bardwood-support-services-ltd-3205655-slash-2022" data-track-action="Employment tribunal decisions.5" data-track-category="navFinderLinkClicked" data-track-label="/employment-tribunal-decisions/mr-a-sesay-v-bardwood-support-services-ltd-3205655-slash-2022" data-track-options='{"dimension28":50,"dimension29":"Mr A Sesay v Bardwood Support Services Ltd: 3205655/2022"}' href="/employment-tribunal-decisions/mr-a-sesay-v-bardwood-support-services-ltd-3205655-slash-2022">Mr A Sesay v Bardwood Support Services Ltd: 3205655/2022</a>,
#  <a class="govuk-link" data-ecommerce-index="6" data-ecommerce-path="/employment-tribunal-decisions/miss-s-a-parminter-v-evolve-child-care-ltd-1402106-slash-2022" data-ecommerce-row="1" data-ga4-ecommerce-path="/employment-tribunal-decisions/miss-s-a-parminter-v-evolve-child-care-ltd-1402106-slash-2022" data-track-action="Employment tribunal decisions.6" data-track-category="navFinderLinkClicked" data-track-label="/employment-tribunal-decisions/miss-s-a-parminter-v-evolve-child-care-ltd-1402106-slash-2022" data-track-options='{"dimension28":50,"dimension29":"Miss S A Parminter v Evolve Child Care Ltd: 1402106/2022"}' href="/employment-tribunal-decisions/miss-s-a-parminter-v-evolve-child-care-ltd-1402106-slash-2022">Miss S A Parminter v Evolve Child Care Ltd: 1402106/2022</a>,
#  <a class="govuk-link" data-ecommerce-index="7" data-ecommerce-path="/employment-tribunal-decisions/ms-s-skuse-v-clyst-hydon-pub-company-ltd-in-creditors-voluntary-liquidation-1403816-slash-2022" data-ecommerce-row="1" data-ga4-ecommerce-path="/employment-tribunal-decisions/ms-s-skuse-v-clyst-hydon-pub-company-ltd-in-creditors-voluntary-liquidation-1403816-slash-2022" data-track-action="Employment tribunal decisions.7" data-track-category="navFinderLinkClicked" data-track-label="/employment-tribunal-decisions/ms-s-skuse-v-clyst-hydon-pub-company-ltd-in-creditors-voluntary-liquidation-1403816-slash-2022" data-track-options='{"dimension28":50,"dimension29":"Ms S Skuse v Clyst Hydon Pub Company Ltd (in Creditors Voluntary Liquidation): 1403816/2022"}' href="/employment-tribunal-decisions/ms-s-skuse-v-clyst-hydon-pub-company-ltd-in-creditors-voluntary-liquidation-1403816-slash-2022">Ms S Skuse v Clyst Hydon Pub Company Ltd (in Creditors Voluntary Liquidation): 1403816/2022</a>,
#  <a class="govuk-link" data-ecommerce-index="8" data-ecommerce-path="/employment-tribunal-decisions/mr-s-george-v-the-brandon-trust-1403216-slash-2022" data-ecommerce-row="1" data-ga4-ecommerce-path="/employment-tribunal-decisions/mr-s-george-v-the-brandon-trust-1403216-slash-2022" data-track-action="Employment tribunal decisions.8" data-track-category="navFinderLinkClicked" data-track-label="/employment-tribunal-decisions/mr-s-george-v-the-brandon-trust-1403216-slash-2022" data-track-options='{"dimension28":50,"dimension29":"Mr S George v The Brandon Trust: 1403216/2022"}' href="/employment-tribunal-decisions/mr-s-george-v-the-brandon-trust-1403216-slash-2022">Mr S George v The Brandon Trust: 1403216/2022</a>,
#  <a class="govuk-link" data-ecommerce-index="9" data-ecommerce-path="/employment-tribunal-decisions/mr-p-thompson-v-devon-and-somerset-fire-and-rescue-service-1401578-slash-2022-and-6000574-slash-2023" data-ecommerce-row="1" data-ga4-ecommerce-path="/employment-tribunal-decisions/mr-p-thompson-v-devon-and-somerset-fire-and-rescue-service-1401578-slash-2022-and-6000574-slash-2023" data-track-action="Employment tribunal decisions.9" data-track-category="navFinderLinkClicked" data-track-label="/employment-tribunal-decisions/mr-p-thompson-v-devon-and-somerset-fire-and-rescue-service-1401578-slash-2022-and-6000574-slash-2023" data-track-options='{"dimension28":50,"dimension29":"Mr P Thompson v Devon and Somerset Fire and Rescue Service: 1401578/2022 and 6000574/2023"}' href="/employment-tribunal-decisions/mr-p-thompson-v-devon-and-somerset-fire-and-rescue-service-1401578-slash-2022-and-6000574-slash-2023">Mr P Thompson v Devon and Somerset Fire and Rescue Service: 1401578/2022 and 6000574/2023</a>,
#  <a class="govuk-link" data-ecommerce-index="10" data-ecommerce-path="/employment-tribunal-decisions/mr-m-o-klimecka-v-customer-dedicated-logistics-6000106-slash-2022" data-ecommerce-row="1" data-ga4-ecommerce-path="/employment-tribunal-decisions/mr-m-o-klimecka-v-customer-dedicated-logistics-6000106-slash-2022" data-track-action="Employment tribunal decisions.10" data-track-category="navFinderLinkClicked" data-track-label="/employment-tribunal-decisions/mr-m-o-klimecka-v-customer-dedicated-logistics-6000106-slash-2022" data-track-options='{"dimension28":50,"dimension29":"Mr M O Klimecka v Customer Dedicated Logistics: 6000106/2022"}' href="/employment-tribunal-decisions/mr-m-o-klimecka-v-customer-dedicated-logistics-6000106-slash-2022">Mr M O Klimecka v Customer Dedicated Logistics: 6000106/2022</a>,
#  <a class="govuk-link" data-ecommerce-index="11" data-ecommerce-path="/employment-tribunal-decisions/mr-l-wilson-v-urban-autos-ltd-in-liquidation-and-the-secretary-of-state-for-business-and-trade-1400062-slash-2023" data-ecommerce-row="1" data-ga4-ecommerce-path="/employment-tribunal-decisions/mr-l-wilson-v-urban-autos-ltd-in-liquidation-and-the-secretary-of-state-for-business-and-trade-1400062-slash-2023" data-track-action="Employment tribunal decisions.11" data-track-category="navFinderLinkClicked" data-track-label="/employment-tribunal-decisions/mr-l-wilson-v-urban-autos-ltd-in-liquidation-and-the-secretary-of-state-for-business-and-trade-1400062-slash-2023" data-track-options='{"dimension28":50,"dimension29":"Mr L Wilson v Urban Autos Ltd (In Liquidation) and The Secretary of State for Business \u0026 Trade: 1400062/2023"}' href="/employment-tribunal-decisions/mr-l-wilson-v-urban-autos-ltd-in-liquidation-and-the-secretary-of-state-for-business-and-trade-1400062-slash-2023">Mr L Wilson v Urban Autos Ltd (In Liquidation) and The Secretary of State for Business &amp; Trade: 1400062/2023</a>,
#  <a class="govuk-link" data-ecommerce-index="12" data-ecommerce-path="/employment-tribunal-decisions/mr-e-reynolds-v-call-the-mechanic-2401727-slash-2023" data-ecommerce-row="1" data-ga4-ecommerce-path="/employment-tribunal-decisions/mr-e-reynolds-v-call-the-mechanic-2401727-slash-2023" data-track-action="Employment tribunal decisions.12" data-track-category="navFinderLinkClicked" data-track-label="/employment-tribunal-decisions/mr-e-reynolds-v-call-the-mechanic-2401727-slash-2023" data-track-options='{"dimension28":50,"dimension29":"Mr E Reynolds v Call The Mechanic: 2401727/2023"}' href="/employment-tribunal-decisions/mr-e-reynolds-v-call-the-mechanic-2401727-slash-2023">Mr E Reynolds v Call The Mechanic: 2401727/2023</a>,
#  <a class="govuk-link" data-ecommerce-index="13" data-ecommerce-path="/employment-tribunal-decisions/mr-d-manfield-v-b-r-rail-ltd-1401195-slash-2023" data-ecommerce-row="1" data-ga4-ecommerce-path="/employment-tribunal-decisions/mr-d-manfield-v-b-r-rail-ltd-1401195-slash-2023" data-track-action="Employment tribunal decisions.13" data-track-category="navFinderLinkClicked" data-track-label="/employment-tribunal-decisions/mr-d-manfield-v-b-r-rail-ltd-1401195-slash-2023" data-track-options='{"dimension28":50,"dimension29":"Mr D Manfield v B R Rail Ltd: 1401195/2023"}' href="/employment-tribunal-decisions/mr-d-manfield-v-b-r-rail-ltd-1401195-slash-2023">Mr D Manfield v B R Rail Ltd: 1401195/2023</a>,
#  <a class="govuk-link" data-ecommerce-index="14" data-ecommerce-path="/employment-tribunal-decisions/mr-a-badru-v-jakk-security-and-facility-managmenet-ltd-1401267-slash-2023" data-ecommerce-row="1" data-ga4-ecommerce-path="/employment-tribunal-decisions/mr-a-badru-v-jakk-security-and-facility-managmenet-ltd-1401267-slash-2023" data-track-action="Employment tribunal decisions.14" data-track-category="navFinderLinkClicked" data-track-label="/employment-tribunal-decisions/mr-a-badru-v-jakk-security-and-facility-managmenet-ltd-1401267-slash-2023" data-track-options='{"dimension28":50,"dimension29":"Mr A Badru v JAKK Security \u0026 Facility Managmenet Ltd: 1401267/2023 "}' href="/employment-tribunal-decisions/mr-a-badru-v-jakk-security-and-facility-managmenet-ltd-1401267-slash-2023">Mr A Badru v JAKK Security &amp; Facility Managmenet Ltd: 1401267/2023 </a>,
#  <a class="govuk-link" data-ecommerce-index="15" data-ecommerce-path="/employment-tribunal-decisions/mrs-n-hulait-v-leicestershire-partnership-nhs-trust-2601594-slash-2022" data-ecommerce-row="1" data-ga4-ecommerce-path="/employment-tribunal-decisions/mrs-n-hulait-v-leicestershire-partnership-nhs-trust-2601594-slash-2022" data-track-action="Employment tribunal decisions.15" data-track-category="navFinderLinkClicked" data-track-label="/employment-tribunal-decisions/mrs-n-hulait-v-leicestershire-partnership-nhs-trust-2601594-slash-2022" data-track-options='{"dimension28":50,"dimension29":"Mrs N Hulait v Leicestershire Partnership NHS Trust: 2601594/2022"}' href="/employment-tribunal-decisions/mrs-n-hulait-v-leicestershire-partnership-nhs-trust-2601594-slash-2022">Mrs N Hulait v Leicestershire Partnership NHS Trust: 2601594/2022</a>,
#  <a class="govuk-link" data-ecommerce-index="16" data-ecommerce-path="/employment-tribunal-decisions/mr-w-nowak-v-a-popat-and-others-2600959-slash-2022" data-ecommerce-row="1" data-ga4-ecommerce-path="/employment-tribunal-decisions/mr-w-nowak-v-a-popat-and-others-2600959-slash-2022" data-track-action="Employment tribunal decisions.16" data-track-category="navFinderLinkClicked" data-track-label="/employment-tribunal-decisions/mr-w-nowak-v-a-popat-and-others-2600959-slash-2022" data-track-options='{"dimension28":50,"dimension29":"Mr W Nowak v A Popat and others: 2600959/2022"}' href="/employment-tribunal-decisions/mr-w-nowak-v-a-popat-and-others-2600959-slash-2022">Mr W Nowak v A Popat and others: 2600959/2022</a>,
#  <a class="govuk-link" data-ecommerce-index="17" data-ecommerce-path="/employment-tribunal-decisions/miss-d-evans-v-only-care-ltd-2600945-slash-2023" data-ecommerce-row="1" data-ga4-ecommerce-path="/employment-tribunal-decisions/miss-d-evans-v-only-care-ltd-2600945-slash-2023" data-track-action="Employment tribunal decisions.17" data-track-category="navFinderLinkClicked" data-track-label="/employment-tribunal-decisions/miss-d-evans-v-only-care-ltd-2600945-slash-2023" data-track-options='{"dimension28":50,"dimension29":"Miss D Evans v Only Care Ltd: 2600945/2023"}' href="/employment-tribunal-decisions/miss-d-evans-v-only-care-ltd-2600945-slash-2023">Miss D Evans v Only Care Ltd: 2600945/2023</a>,
#  <a class="govuk-link" data-ecommerce-index="18" data-ecommerce-path="/employment-tribunal-decisions/ms-c-josey-v-intesa-leicester-ltd-2602064-slash-2022" data-ecommerce-row="1" data-ga4-ecommerce-path="/employment-tribunal-decisions/ms-c-josey-v-intesa-leicester-ltd-2602064-slash-2022" data-track-action="Employment tribunal decisions.18" data-track-category="navFinderLinkClicked" data-track-label="/employment-tribunal-decisions/ms-c-josey-v-intesa-leicester-ltd-2602064-slash-2022" data-track-options='{"dimension28":50,"dimension29":"Ms C Josey v Intesa (Leicester) Ltd: 2602064/2022"}' href="/employment-tribunal-decisions/ms-c-josey-v-intesa-leicester-ltd-2602064-slash-2022">Ms C Josey v Intesa (Leicester) Ltd: 2602064/2022</a>,
#  <a class="govuk-link" data-ecommerce-index="19" data-ecommerce-path="/employment-tribunal-decisions/mr-k-l-haytack-v-precedent-surveyors-ltd-1803215-slash-2023" data-ecommerce-row="1" data-ga4-ecommerce-path="/employment-tribunal-decisions/mr-k-l-haytack-v-precedent-surveyors-ltd-1803215-slash-2023" data-track-action="Employment tribunal decisions.19" data-track-category="navFinderLinkClicked" data-track-label="/employment-tribunal-decisions/mr-k-l-haytack-v-precedent-surveyors-ltd-1803215-slash-2023" data-track-options='{"dimension28":50,"dimension29":"Mr K L Haytack v Precedent Surveyors Ltd: 1803215/2023"}' href="/employment-tribunal-decisions/mr-k-l-haytack-v-precedent-surveyors-ltd-1803215-slash-2023">Mr K L Haytack v Precedent Surveyors Ltd: 1803215/2023</a>,
#  <a class="govuk-link" data-ecommerce-index="20" data-ecommerce-path="/employment-tribunal-decisions/mr-j-mayanja-v-bradford-metropolitan-borough-council-1801632-slash-2022" data-ecommerce-row="1" data-ga4-ecommerce-path="/employment-tribunal-decisions/mr-j-mayanja-v-bradford-metropolitan-borough-council-1801632-slash-2022" data-track-action="Employment tribunal decisions.20" data-track-category="navFinderLinkClicked" data-track-label="/employment-tribunal-decisions/mr-j-mayanja-v-bradford-metropolitan-borough-council-1801632-slash-2022" data-track-options='{"dimension28":50,"dimension29":"Mr J Mayanja v Bradford Metropolitan Borough Council: 1801632/2022"}' href="/employment-tribunal-decisions/mr-j-mayanja-v-bradford-metropolitan-borough-council-1801632-slash-2022">Mr J Mayanja v Bradford Metropolitan Borough Council: 1801632/2022</a>,
#  <a class="govuk-link" data-ecommerce-index="21" data-ecommerce-path="/employment-tribunal-decisions/mrs-s-messum-v-bradford-management-services-ltd-and-others-1802792-slash-2021" data-ecommerce-row="1" data-ga4-ecommerce-path="/employment-tribunal-decisions/mrs-s-messum-v-bradford-management-services-ltd-and-others-1802792-slash-2021" data-track-action="Employment tribunal decisions.21" data-track-category="navFinderLinkClicked" data-track-label="/employment-tribunal-decisions/mrs-s-messum-v-bradford-management-services-ltd-and-others-1802792-slash-2021" data-track-options='{"dimension28":50,"dimension29":"Mrs S Messum v Bradford Management Services Ltd and others: 1802792/2021"}' href="/employment-tribunal-decisions/mrs-s-messum-v-bradford-management-services-ltd-and-others-1802792-slash-2021">Mrs S Messum v Bradford Management Services Ltd and others: 1802792/2021</a>,
#  <a class="govuk-link" data-ecommerce-index="22" data-ecommerce-path="/employment-tribunal-decisions/mr-n-rawle-v-stakestar-ltd-in-voluntary-liquidation-1803216-slash-2023" data-ecommerce-row="1" data-ga4-ecommerce-path="/employment-tribunal-decisions/mr-n-rawle-v-stakestar-ltd-in-voluntary-liquidation-1803216-slash-2023" data-track-action="Employment tribunal decisions.22" data-track-category="navFinderLinkClicked" data-track-label="/employment-tribunal-decisions/mr-n-rawle-v-stakestar-ltd-in-voluntary-liquidation-1803216-slash-2023" data-track-options='{"dimension28":50,"dimension29":"Mr N Rawle v Stakestar Ltd (in Voluntary Liquidation): 1803216/2023"}' href="/employment-tribunal-decisions/mr-n-rawle-v-stakestar-ltd-in-voluntary-liquidation-1803216-slash-2023">Mr N Rawle v Stakestar Ltd (in Voluntary Liquidation): 1803216/2023</a>,
#  <a class="govuk-link" data-ecommerce-index="23" data-ecommerce-path="/employment-tribunal-decisions/miss-m-tafa-v-hull-university-teaching-hospitals-nhs-trust-6000025-slash-2022" data-ecommerce-row="1" data-ga4-ecommerce-path="/employment-tribunal-decisions/miss-m-tafa-v-hull-university-teaching-hospitals-nhs-trust-6000025-slash-2022" data-track-action="Employment tribunal decisions.23" data-track-category="navFinderLinkClicked" data-track-label="/employment-tribunal-decisions/miss-m-tafa-v-hull-university-teaching-hospitals-nhs-trust-6000025-slash-2022" data-track-options='{"dimension28":50,"dimension29":"Miss M Tafa v Hull University Teaching Hospitals NHS Trust: 6000025/2022"}' href="/employment-tribunal-decisions/miss-m-tafa-v-hull-university-teaching-hospitals-nhs-trust-6000025-slash-2022">Miss M Tafa v Hull University Teaching Hospitals NHS Trust: 6000025/2022</a>,
#  <a class="govuk-link" data-ecommerce-index="24" data-ecommerce-path="/employment-tribunal-decisions/mr-s-blackburn-v-j-blackburn-and-sons-ltd-in-creditors-voluntary-liquidation-and-secretary-of-state-for-business-energy-and-industrial-strategy-1803171-slash-2023" data-ecommerce-row="1" data-ga4-ecommerce-path="/employment-tribunal-decisions/mr-s-blackburn-v-j-blackburn-and-sons-ltd-in-creditors-voluntary-liquidation-and-secretary-of-state-for-business-energy-and-industrial-strategy-1803171-slash-2023" data-track-action="Employment tribunal decisions.24" data-track-category="navFinderLinkClicked" data-track-label="/employment-tribunal-decisions/mr-s-blackburn-v-j-blackburn-and-sons-ltd-in-creditors-voluntary-liquidation-and-secretary-of-state-for-business-energy-and-industrial-strategy-1803171-slash-2023" data-track-options='{"dimension28":50,"dimension29":"Mr S Blackburn v J Blackburn and Sons Ltd (In Creditors’ Voluntary Liquidation) and Secretary of State for Business Energy and Industrial Strategy: 1803171/2023"}' href="/employment-tribunal-decisions/mr-s-blackburn-v-j-blackburn-and-sons-ltd-in-creditors-voluntary-liquidation-and-secretary-of-state-for-business-energy-and-industrial-strategy-1803171-slash-2023">Mr S Blackburn v J Blackburn and Sons Ltd (In Creditors’ Voluntary Liquidation) and Secretary of State for Business Energy and Industrial Strategy: 1803171/2023</a>,
#  <a class="govuk-link" data-ecommerce-index="25" data-ecommerce-path="/employment-tribunal-decisions/miss-s-benn-v-boots-management-services-ltd-1801501-slash-2023" data-ecommerce-row="1" data-ga4-ecommerce-path="/employment-tribunal-decisions/miss-s-benn-v-boots-management-services-ltd-1801501-slash-2023" data-track-action="Employment tribunal decisions.25" data-track-category="navFinderLinkClicked" data-track-label="/employment-tribunal-decisions/miss-s-benn-v-boots-management-services-ltd-1801501-slash-2023" data-track-options='{"dimension28":50,"dimension29":"Miss S Benn v Boots Management Services Ltd: 1801501/2023"}' href="/employment-tribunal-decisions/miss-s-benn-v-boots-management-services-ltd-1801501-slash-2023">Miss S Benn v Boots Management Services Ltd: 1801501/2023</a>,
#  <a class="govuk-link" data-ecommerce-index="26" data-ecommerce-path="/employment-tribunal-decisions/mrs-c-cox-and-mr-m-jefferson-v-neuro-case-management-corporation-ltd-1803204-slash-2023-and-1803205-slash-2023" data-ecommerce-row="1" data-ga4-ecommerce-path="/employment-tribunal-decisions/mrs-c-cox-and-mr-m-jefferson-v-neuro-case-management-corporation-ltd-1803204-slash-2023-and-1803205-slash-2023" data-track-action="Employment tribunal decisions.26" data-track-category="navFinderLinkClicked" data-track-label="/employment-tribunal-decisions/mrs-c-cox-and-mr-m-jefferson-v-neuro-case-management-corporation-ltd-1803204-slash-2023-and-1803205-slash-2023" data-track-options='{"dimension28":50,"dimension29":"Mrs C Cox and Mr M Jefferson v Neuro Case Management Corporation Ltd: 1803204/2023 and 1803205/2023"}' href="/employment-tribunal-decisions/mrs-c-cox-and-mr-m-jefferson-v-neuro-case-management-corporation-ltd-1803204-slash-2023-and-1803205-slash-2023">Mrs C Cox and Mr M Jefferson v Neuro Case Management Corporation Ltd: 1803204/2023 and 1803205/2023</a>,
#  <a class="govuk-link" data-ecommerce-index="27" data-ecommerce-path="/employment-tribunal-decisions/mr-d-morgan-v-orridge-and-company-ltd-8000039-slash-2022" data-ecommerce-row="1" data-ga4-ecommerce-path="/employment-tribunal-decisions/mr-d-morgan-v-orridge-and-company-ltd-8000039-slash-2022" data-track-action="Employment tribunal decisions.27" data-track-category="navFinderLinkClicked" data-track-label="/employment-tribunal-decisions/mr-d-morgan-v-orridge-and-company-ltd-8000039-slash-2022" data-track-options='{"dimension28":50,"dimension29":"Mr D Morgan v Orridge \u0026 Company Ltd: 8000039/2022"}' href="/employment-tribunal-decisions/mr-d-morgan-v-orridge-and-company-ltd-8000039-slash-2022">Mr D Morgan v Orridge &amp; Company Ltd: 8000039/2022</a>,
#  <a class="govuk-link" data-ecommerce-index="28" data-ecommerce-path="/employment-tribunal-decisions/ms-m-mccormick-v-north-lanarkshire-womens-aid-ltd-8000064-slash-2023" data-ecommerce-row="1" data-ga4-ecommerce-path="/employment-tribunal-decisions/ms-m-mccormick-v-north-lanarkshire-womens-aid-ltd-8000064-slash-2023" data-track-action="Employment tribunal decisions.28" data-track-category="navFinderLinkClicked" data-track-label="/employment-tribunal-decisions/ms-m-mccormick-v-north-lanarkshire-womens-aid-ltd-8000064-slash-2023" data-track-options='{"dimension28":50,"dimension29":"Ms M Mccormick v North Lanarkshire Women’s Aid Ltd: 8000064/2023"}' href="/employment-tribunal-decisions/ms-m-mccormick-v-north-lanarkshire-womens-aid-ltd-8000064-slash-2023">Ms M Mccormick v North Lanarkshire Women’s Aid Ltd: 8000064/2023</a>,
#  <a class="govuk-link" data-ecommerce-index="29" data-ecommerce-path="/employment-tribunal-decisions/mr-a-gorski-v-miller-fabrications-ltd-4107497-slash-2022" data-ecommerce-row="1" data-ga4-ecommerce-path="/employment-tribunal-decisions/mr-a-gorski-v-miller-fabrications-ltd-4107497-slash-2022" data-track-action="Employment tribunal decisions.29" data-track-category="navFinderLinkClicked" data-track-label="/employment-tribunal-decisions/mr-a-gorski-v-miller-fabrications-ltd-4107497-slash-2022" data-track-options='{"dimension28":50,"dimension29":"Mr A Gorski v Miller Fabrications Ltd: 4107497/2022"}' href="/employment-tribunal-decisions/mr-a-gorski-v-miller-fabrications-ltd-4107497-slash-2022">Mr A Gorski v Miller Fabrications Ltd: 4107497/2022</a>,
#  <a class="govuk-link" data-ecommerce-index="30" data-ecommerce-path="/employment-tribunal-decisions/mr-w-purcell-v-screen-ink-and-solvent-supplies-ltd-2414855-slash-2021" data-ecommerce-row="1" data-ga4-ecommerce-path="/employment-tribunal-decisions/mr-w-purcell-v-screen-ink-and-solvent-supplies-ltd-2414855-slash-2021" data-track-action="Employment tribunal decisions.30" data-track-category="navFinderLinkClicked" data-track-label="/employment-tribunal-decisions/mr-w-purcell-v-screen-ink-and-solvent-supplies-ltd-2414855-slash-2021" data-track-options='{"dimension28":50,"dimension29":"Mr W Purcell v Screen Ink and Solvent Supplies Ltd: 2414855/2021"}' href="/employment-tribunal-decisions/mr-w-purcell-v-screen-ink-and-solvent-supplies-ltd-2414855-slash-2021">Mr W Purcell v Screen Ink and Solvent Supplies Ltd: 2414855/2021</a>,
# ...
#  </svg>Get emails
#  </a>,
#  <a class="govuk-link govuk-link--no-underline gem-c-subscription-links__item gem-c-subscription-links__item--link" href="/employment-tribunal-decisions.atom"> <svg aria-hidden="true" class="gem-c-subscription-links__icon" fill="currentColor" focusable="false" height="15" width="15" xmlns="http://www.w3.org/2000/svg"><path d="M1.996 11A2 2 0 0 0 0 12.993c0 1.101.895 1.99 1.996 1.99 1.106 0 2-.889 2-1.99a2 2 0 0 0-2-1.993zM.002 5.097V7.97c1.872 0 3.632.733 4.958 2.059A6.984 6.984 0 0 1 7.015 15h2.888c0-5.461-4.443-9.903-9.9-9.903zM.006 0v2.876c6.676 0 12.11 5.44 12.11 12.124H15C15 6.731 8.273 0 .006 0z"></path>
#  </svg>Subscribe to feed
#  </a>,
#  <a aria-hidden="true" class="gem-c-feedback__prompt-link" data-track-action="ffMaybeClick" data-track-category="yesNoFeedbackForm" hidden="hidden" href="/contact/govuk" role="button">
#                Maybe
#  </a>,
#  <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"1","index_section":"1","index_section_count":"5"},"index_total":"16","section":"Services and information"}' data-track-action="topicsLink" data-track-category="footerClicked" data-track-label="/browse/benefits" data-track-options='{"dimension29":"Benefits"}' href="/browse/benefits">Benefits</a>,
#  <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"2","index_section":"1","index_section_count":"5"},"index_total":"16","section":"Services and information"}' data-track-action="topicsLink" data-track-category="footerClicked" data-track-label="/browse/births-deaths-marriages" data-track-options='{"dimension29":"Births, death, marriages and care"}' href="/browse/births-deaths-marriages">Births, death, marriages and care</a>,
#  <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"3","index_section":"1","index_section_count":"5"},"index_total":"16","section":"Services and information"}' data-track-action="topicsLink" data-track-category="footerClicked" data-track-label="/browse/business" data-track-options='{"dimension29":"Business and self-employed"}' href="/browse/business">Business and self-employed</a>,
#  <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"4","index_section":"1","index_section_count":"5"},"index_total":"16","section":"Services and information"}' data-track-action="topicsLink" data-track-category="footerClicked" data-track-label="/browse/childcare-parenting" data-track-options='{"dimension29":"Childcare and parenting"}' href="/browse/childcare-parenting">Childcare and parenting</a>,
#  <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"5","index_section":"1","index_section_count":"5"},"index_total":"16","section":"Services and information"}' data-track-action="topicsLink" data-track-category="footerClicked" data-track-label="/browse/citizenship" data-track-options='{"dimension29":"Citizenship and living in the UK"}' href="/browse/citizenship">Citizenship and living in the UK</a>,
#  <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"6","index_section":"1","index_section_count":"5"},"index_total":"16","section":"Services and information"}' data-track-action="topicsLink" data-track-category="footerClicked" data-track-label="/browse/justice" data-track-options='{"dimension29":"Crime, justice and the law"}' href="/browse/justice">Crime, justice and the law</a>,
#  <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"7","index_section":"1","index_section_count":"5"},"index_total":"16","section":"Services and information"}' data-track-action="topicsLink" data-track-category="footerClicked" data-track-label="/browse/disabilities" data-track-options='{"dimension29":"Disabled people"}' href="/browse/disabilities">Disabled people</a>,
#  <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"8","index_section":"1","index_section_count":"5"},"index_total":"16","section":"Services and information"}' data-track-action="topicsLink" data-track-category="footerClicked" data-track-label="/browse/driving" data-track-options='{"dimension29":"Driving and transport"}' href="/browse/driving">Driving and transport</a>,
#  <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"9","index_section":"1","index_section_count":"5"},"index_total":"16","section":"Services and information"}' data-track-action="topicsLink" data-track-category="footerClicked" data-track-label="/browse/education" data-track-options='{"dimension29":"Education and learning"}' href="/browse/education">Education and learning</a>,
#  <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"10","index_section":"1","index_section_count":"5"},"index_total":"16","section":"Services and information"}' data-track-action="topicsLink" data-track-category="footerClicked" data-track-label="/browse/employing-people" data-track-options='{"dimension29":"Employing people"}' href="/browse/employing-people">Employing people</a>,
#  <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"11","index_section":"1","index_section_count":"5"},"index_total":"16","section":"Services and information"}' data-track-action="topicsLink" data-track-category="footerClicked" data-track-label="/browse/environment-countryside" data-track-options='{"dimension29":"Environment and countryside"}' href="/browse/environment-countryside">Environment and countryside</a>,
#  <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"12","index_section":"1","index_section_count":"5"},"index_total":"16","section":"Services and information"}' data-track-action="topicsLink" data-track-category="footerClicked" data-track-label="/browse/housing-local-services" data-track-options='{"dimension29":"Housing and local services"}' href="/browse/housing-local-services">Housing and local services</a>,
#  <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"13","index_section":"1","index_section_count":"5"},"index_total":"16","section":"Services and information"}' data-track-action="topicsLink" data-track-category="footerClicked" data-track-label="/browse/tax" data-track-options='{"dimension29":"Money and tax"}' href="/browse/tax">Money and tax</a>,
#  <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"14","index_section":"1","index_section_count":"5"},"index_total":"16","section":"Services and information"}' data-track-action="topicsLink" data-track-category="footerClicked" data-track-label="/browse/abroad" data-track-options='{"dimension29":"Passports, travel and living abroad"}' href="/browse/abroad">Passports, travel and living abroad</a>,
#  <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"15","index_section":"1","index_section_count":"5"},"index_total":"16","section":"Services and information"}' data-track-action="topicsLink" data-track-category="footerClicked" data-track-label="/browse/visas-immigration" data-track-options='{"dimension29":"Visas and immigration"}' href="/browse/visas-immigration">Visas and immigration</a>,
#  <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"16","index_section":"1","index_section_count":"5"},"index_total":"16","section":"Services and information"}' data-track-action="topicsLink" data-track-category="footerClicked" data-track-label="/browse/working" data-track-options='{"dimension29":"Working, jobs and pensions"}' href="/browse/working">Working, jobs and pensions</a>,
#  <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"1","index_section":"2","index_section_count":"5"},"index_total":"8","section":"Government activity"}' data-track-action="governmentactivityLink" data-track-category="footerClicked" data-track-label="/government/organisations" data-track-options='{"dimension29":"Departments"}' href="/government/organisations">Departments</a>,
#  <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"2","index_section":"2","index_section_count":"5"},"index_total":"8","section":"Government activity"}' data-track-action="governmentactivityLink" data-track-category="footerClicked" data-track-label="/search/news-and-communications" data-track-options='{"dimension29":"News"}' href="/search/news-and-communications">News</a>,
#  <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"3","index_section":"2","index_section_count":"5"},"index_total":"8","section":"Government activity"}' data-track-action="governmentactivityLink" data-track-category="footerClicked" data-track-label="/search/guidance-and-regulation" data-track-options='{"dimension29":"Guidance and regulation"}' href="/search/guidance-and-regulation">Guidance and regulation</a>,
#  <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"4","index_section":"2","index_section_count":"5"},"index_total":"8","section":"Government activity"}' data-track-action="governmentactivityLink" data-track-category="footerClicked" data-track-label="/search/research-and-statistics" data-track-options='{"dimension29":"Research and statistics"}' href="/search/research-and-statistics">Research and statistics</a>,
#  <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"5","index_section":"2","index_section_count":"5"},"index_total":"8","section":"Government activity"}' data-track-action="governmentactivityLink" data-track-category="footerClicked" data-track-label="/search/policy-papers-and-consultations" data-track-options='{"dimension29":"Policy papers and consultations"}' href="/search/policy-papers-and-consultations">Policy papers and consultations</a>,
#  <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"6","index_section":"2","index_section_count":"5"},"index_total":"8","section":"Government activity"}' data-track-action="governmentactivityLink" data-track-category="footerClicked" data-track-label="/search/transparency-and-freedom-of-information-releases" data-track-options='{"dimension29":"Transparency"}' href="/search/transparency-and-freedom-of-information-releases">Transparency</a>,
#  <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"7","index_section":"2","index_section_count":"5"},"index_total":"8","section":"Government activity"}' data-track-action="governmentactivityLink" data-track-category="footerClicked" data-track-label="/government/how-government-works" data-track-options='{"dimension29":"How government works"}' href="/government/how-government-works">How government works</a>,
#  <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"8","index_section":"2","index_section_count":"5"},"index_total":"8","section":"Government activity"}' data-track-action="governmentactivityLink" data-track-category="footerClicked" data-track-label="/government/get-involved" data-track-options='{"dimension29":"Get involved"}' href="/government/get-involved">Get involved</a>,
#  <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"1","index_section":"3","index_section_count":"5"},"index_total":"8","section":"Support links"}' data-track-action="supportLink" data-track-category="footerClicked" data-track-label="/help" data-track-options='{"dimension29":"Help"}' href="/help">Help</a>,
#  <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"2","index_section":"3","index_section_count":"5"},"index_total":"8","section":"Support links"}' data-track-action="supportLink" data-track-category="footerClicked" data-track-label="/help/privacy-notice" data-track-options='{"dimension29":"Privacy"}' href="/help/privacy-notice">Privacy</a>,
#  <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"3","index_section":"3","index_section_count":"5"},"index_total":"8","section":"Support links"}' data-track-action="supportLink" data-track-category="footerClicked" data-track-label="/help/cookies" data-track-options='{"dimension29":"Cookies"}' href="/help/cookies">Cookies</a>,
#  <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"4","index_section":"3","index_section_count":"5"},"index_total":"8","section":"Support links"}' data-track-action="supportLink" data-track-category="footerClicked" data-track-label="/help/accessibility-statement" data-track-options='{"dimension29":"Accessibility statement"}' href="/help/accessibility-statement">Accessibility statement</a>,
#  <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"5","index_section":"3","index_section_count":"5"},"index_total":"8","section":"Support links"}' data-track-action="supportLink" data-track-category="footerClicked" data-track-label="/contact" data-track-options='{"dimension29":"Contact"}' href="/contact">Contact</a>,
#  <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"6","index_section":"3","index_section_count":"5"},"index_total":"8","section":"Support links"}' data-track-action="supportLink" data-track-category="footerClicked" data-track-label="/help/terms-conditions" data-track-options='{"dimension29":"Terms and conditions"}' href="/help/terms-conditions">Terms and conditions</a>,
#  <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"7","index_section":"3","index_section_count":"5"},"index_total":"8","section":"Support links"}' data-track-action="supportLink" data-track-category="footerClicked" data-track-label="/cymraeg" data-track-options='{"dimension29":"Rhestr o Wasanaethau Cymraeg"}' href="/cymraeg" lang="cy">Rhestr o Wasanaethau Cymraeg</a>,
#  <a class="govuk-footer__link" data-ga4-link='{"event_name":"navigation","type":"footer","index":{"index_link":"8","index_section":"3","index_section_count":"5"},"index_total":"8","section":"Support links"}' data-track-action="supportLink" data-track-category="footerClicked" data-track-label="/government/organisations/government-digital-service" data-track-options='{"dimension29":"Government Digital Service"}' href="/government/organisations/government-digital-service">Government Digital Service</a>,
#  <a class="govuk-footer__link" href="https://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/" rel="license">Open Government Licence v3.0</a>,
#  <a class="govuk-footer__link govuk-footer__copyright-logo" href="https://www.nationalarchives.gov.uk/information-management/re-using-public-sector-information/uk-government-licensing-framework/crown-copyright/">© Crown copyright</a>]

# %% [markdown]
# ### Measuring the length, and showing just one result
#
# We might want to know how many results we have got. To do that we can use Python's `len()` function (short for 'length') which tells you how many items there are in a list (how long it is).
#
# We also might want to look at the first or last item in the list to see which item it grabs first or last. To do that we can use an index like `[0]` for 'the first' and `[-1]` for 'the last'.
#
# In both cases it makes sense to store the results in a variable first - we will call this 'cases'.

# %%
#create a variable called 'cases'
#and use it to store the results of selecting all <a> tags in 'soup'
cases = soup.select('a')

#print the length
print(len(cases))

#print the first match
print(cases[0])
# Out:
# 133
# <a class="gem-c-skip-link govuk-skip-link govuk-!-display-none-print" data-module="govuk-skip-link" href="#content">Skip to main content</a>

# %% [markdown]
# ### Refining our selector
#
# We now know that the selector grabbed over 100 links. And looking at what has been grabbed, we can see that it's getting links we don't want too.
#
# We don't just want *all* the links - we just want the links to tribunal decisions.
#
# We need to look at the HTML for those links to see if they have some additional attributes we can target - or if we can target a parent tag that contains the same information.

# %% [markdown]
# ### Using the Inspector
#
#
# You can do that by viewing the source HTML underneath the page, but [using the Inspector](https://blog.hubspot.com/website/how-to-inspect) is an even quicker way to do that.
#
# If you right-click on a link (or anything else) and select **Inspect**, this will open the Inspector with the specific HTML for that element highlighted.
#
# The HTML for one of the tribunal links is quite long, with lots of attributes. It helps to copy it into a separate file and break it up by putting each new attribute on its own line, like so:
#
# ```
# <a
# data-ga4-ecommerce-path="/employment-tribunal-decisions/mrs-p-marques-v-just-kidd-inn-ltd-3200680-slash-2023"
# data-ecommerce-path="/employment-tribunal-decisions/mrs-p-marques-v-just-kidd-inn-ltd-3200680-slash-2023"
# data-ecommerce-row="1"
# data-ecommerce-index="2"
# data-track-category="navFinderLinkClicked"
# data-track-action="Employment tribunal decisions.2"
# data-track-label="/employment-tribunal-decisions/mrs-p-marques-v-just-kidd-inn-ltd-3200680-slash-2023"
# data-track-options="{&quot;dimension28&quot;:50,&quot;dimension29&quot;:&quot;Mrs P Marques v Just Kidd Inn Ltd: 3200680/2023&quot;}"
# class="  govuk-link"
# href="/employment-tribunal-decisions/mrs-p-marques-v-just-kidd-inn-ltd-3200680-slash-2023">
# Mrs P Marques v Just Kidd Inn Ltd: 3200680/2023</a>
# ```
#
# There are 10 different attributes here, including the `href=` attribute that defines which URL the linked text will take you to when clicked.

# %% [markdown]
# ### Using a parent tag
#
# If the specific tag you want to target is problematic, it's worth looking at the tags around it. In particular, look for tags which *contain* your tag - called **parent** tags. Parent tags can often be targeted to gather the same information.
#
# The Inspector helpfully formats the HTML to make it easy to see if a tag is a parent tag (or, conversely, a **child** of a parent tag), by indenting tags:
#
# * A tag indented below another is a child tag. The tag above (which is indented less) is its parent tag.
# * Two tags which are indented the same amount are **siblings**: that is, they both share the same parent, and neither is a parent to the other.
#
# In this case the `<a>` tag is indented below a `<div>` tag, so we might turn our attention to that.
#
# Here's the `div` tag in full:
#
# `<div class="gem-c-document-list__item-title">`
#
# This tag contains the `<a>` tag and nothing else, and as it's much simpler it is easier to target.
#
# The `class=` attribute is something we will need to include because `<div>` is a frequently used tag and there are likely to be others elsewhere on the page that we don't want.

# %%
#grab all the <div> tags with class="gem-c-document-list__item-title"
divswewant = soup.select('div[class="gem-c-document-list__item-title"]')
#show how many items we got
print(len(divswewant))
#print the first item
print(divswewant[0])
#print the last item
print(divswewant[-1])
# Out:
# 50
# <div class="gem-c-document-list__item-title"> <a class="govuk-link" data-ecommerce-index="1" data-ecommerce-path="/employment-tribunal-decisions/ms-i-m-de-araujo-ramos-fernandes-v-eden-brook-home-care-ltd-3205112-slash-2022" data-ecommerce-row="1" data-ga4-ecommerce-path="/employment-tribunal-decisions/ms-i-m-de-araujo-ramos-fernandes-v-eden-brook-home-care-ltd-3205112-slash-2022" data-track-action="Employment tribunal decisions.1" data-track-category="navFinderLinkClicked" data-track-label="/employment-tribunal-decisions/ms-i-m-de-araujo-ramos-fernandes-v-eden-brook-home-care-ltd-3205112-slash-2022" data-track-options='{"dimension28":50,"dimension29":"Ms I M de Araújo Ramos Fernandes v Eden Brook Home Care Ltd: 3205112/2022"}' href="/employment-tribunal-decisions/ms-i-m-de-araujo-ramos-fernandes-v-eden-brook-home-care-ltd-3205112-slash-2022">Ms I M de Araújo Ramos Fernandes v Eden Brook Home Care Ltd: 3205112/2022</a>
# </div>
# <div class="gem-c-document-list__item-title"> <a class="govuk-link" data-ecommerce-index="50" data-ecommerce-path="/employment-tribunal-decisions/mr-r-oliver-v-d-andrews-1803155-slash-2023" data-ecommerce-row="1" data-ga4-ecommerce-path="/employment-tribunal-decisions/mr-r-oliver-v-d-andrews-1803155-slash-2023" data-track-action="Employment tribunal decisions.50" data-track-category="navFinderLinkClicked" data-track-label="/employment-tribunal-decisions/mr-r-oliver-v-d-andrews-1803155-slash-2023" data-track-options='{"dimension28":50,"dimension29":"Mr R Oliver v D Andrews: 1803155/2023"}' href="/employment-tribunal-decisions/mr-r-oliver-v-d-andrews-1803155-slash-2023">Mr R Oliver v D Andrews: 1803155/2023</a>
# </div>

# %% [markdown]
# This is much better: we get the amount of results we want, and the first and last items match what we would expect it to be (the first and last cases).

# %% [markdown]
# ### Shifting our attention to another tag: `<time>`
#
# We can repeat the same process for another piece of information: the date.
#
# The HTML containing that information is:
#
# `<time datetime="2023-08-04">4 August 2023</time>`
#
# This is very promising: `<time>` is a very specific tag that we might hope isn't used anywhere else on the page.
#
# Let's find out - we're hoping to see 50 results when we grab them.

# %%
#this grabs the <time> tags
times = soup.select('time')
#check the length
print(len(times))
#check the first
print(times[0])
#check the last
print(times[-1])
# Out:
# 50
# <time datetime="2023-08-04">4 August 2023</time>
# <time datetime="2023-08-03">3 August 2023</time>

# %% [markdown]
# ## Grabbing just the text: `.get_text()`
#
# So far we've grabbed tags *and* their contents. That might be fine - we could clean it up in a spreadsheet, for example - but there is a way to grab just the text inside the tags: `.get_text()`
#
# Here's an example of using it an item with each list:

# %%
#grab the first item from the list 'divswewant'
#apply the .get_text() method to it to grab the text
divswewant[0].get_text()
# Out:
# ' Ms I M de Araújo Ramos Fernandes v Eden Brook Home Care Ltd: 3205112/2022\n'

# %%
#grab the first item from the list 'cases'
#apply the .get_text() method to it to grab the text
times[0].get_text()
# Out:
# '4 August 2023'

# %% [markdown]
# ## Using a loop to create a new list of text entries
#
# We can generate a new list from our existing list of tag-and-text entries by applying to `.get_text()` to each of the entries in turn, then adding the resulting text to a new list.
#
# To do this we:
#
# * Create an empty list
# * Loop through the items in the existing list (of tags-and-text)
# * Apply `.get_text()` to each item
# * Add the resulting text to the empty list (which is now not empty any more)
#
# Once the loop has finished, our previously empty list should be full of the extracted text.
#
# Here's the code:

# %%
#create an empty list
casetitles = []

#loop through the divswewant list
for i in divswewant:
  #extract the text
  casename = i.get_text()
  #add the text and link to the previously empty lists
  casetitles.append(casename)

#show the first 5 rows
casetitles[:5]
# Out:
# [' Ms I M de Araújo Ramos Fernandes v Eden Brook Home Care Ltd: 3205112/2022\n',
#  ' Mrs P Marques v Just Kidd Inn Ltd: 3200680/2023\n',
#  ' Mrs K Janusz v ABC Distribution Ltd: 3200710/2023\n',
#  ' Mr D Singh v Wanis Management Services LLP: 3200018/2023\n',
#  ' Mr A Sesay v Bardwood Support Services Ltd: 3205655/2022\n']

# %%
#create an empty list
datelist = []

#loop through the divswewant list
for i in times:
  #extract the text
  timetext = i.get_text()
  #add the text and link to the previously empty lists
  datelist.append(timetext)

#show the first 5 rows
datelist[:5]
# Out:
# ['4 August 2023',
#  '15 August 2023',
#  '15 August 2023',
#  '2 August 2023',
#  '15 August 2023']

# %% [markdown]
# ## Creating a dataframe from those lists
#
# Lists can be used to make the columns in a dataframe.
#
# To create a dataframe use the `pandas` function `DataFrame()`.
#
# Note the capitalisation on the function name: the D and F must both be upper case for it to work (with no spaces).
#
# Because it's a `pandas` function, we need to name the library as well. And because the `pandas` library was imported as `pd`, that's the name we use: so, `pd.DataFrame()`
#
# The main ingredient for the function `pd.DataFrame()` is the data you want to add. This can be in the form of a **dictionary**.
#
# The dictionary object that we create below has two keys - `"case name"` and `"date"`. The keys are used as column names.
#
# Against each key are two values - and in this case each value is not just one value, but a whole list. A list will be treated as a column of values to go under each column name.

# %%
#create a new dataframe which uses those two lists as its two columns
casedataframe = pd.DataFrame({"case name" : casetitles, "date" : datelist})

#show the first 5 rows
casedataframe[:5]
# Out:
#                                            case name            date
# 0   Ms I M de Araújo Ramos Fernandes v Eden Brook...   4 August 2023
# 1   Mrs P Marques v Just Kidd Inn Ltd: 3200680/20...  15 August 2023
# 2   Mrs K Janusz v ABC Distribution Ltd: 3200710/...  15 August 2023
# 3   Mr D Singh v Wanis Management Services LLP: 3...   2 August 2023
# 4   Mr A Sesay v Bardwood Support Services Ltd: 3...  15 August 2023

# %% [markdown]
# ## Export the data
#
# Now we have a dataframe, we can export it. To do that add `.to_csv()` to the dataframe, and put the name of the file you want to export it as inside the brackets, remembering to include quotation marks.

# %%
casedataframe.to_csv("tribunaldata.csv")

# %% [markdown]
# That data can now be downloaded from the **Files** area (the folder icon) on the left of the Colab notebook.

# %% [markdown]
# ## Bonus: extract the `datetime` attribute
#
# In our code above we grabbed the text for the date of each tribunal - but this data was also encoded within the HTML tag that contained it, in YYYY-MM-DD format:
#
# `<time datetime="2022-02-07">7 February 2022</time>`
#
# Quite often the data that we want (or would prefer) is stored in this way.
#
# For example, if we want the URLs for any linked text, we would need to grab the value of the `href=` attribute.
#
# This means we need something other than `.get_text()` to grab it.
#
# To extract an attribute you need to add the name of the attribute as a string inside square brackets after a match item (*not after the whole list*), like so:
#
# `['datetime']`
#
# `['href']`
#
# Here's some code putting that into practice in different ways:

# %%
#show the first match in full
print(times[0])
#now show the datetime attribute of that match
print(times[0]['datetime'])
# Out:
# <time datetime="2023-08-04">4 August 2023</time>
# 2023-08-04

# %% [markdown]
# And now, a loop to grab them all and put them in a list.

# %%
#create an empty list
timeslist = []

#loop through the times
for i in times:
  #extract the text inside datetime=""
  datetimevalue = i['datetime']
  #add it to our list
  timeslist.append(datetimevalue)

#check the first 5 results
timeslist[:5]
# Out:
# ['2023-08-04', '2023-08-15', '2023-08-15', '2023-08-02', '2023-08-15']

# %% [markdown]
# ## Bonus: extracting parts of a string
#
# It's worth pointing out that you can do additional work in Python to extract just part of the data you have.
#
# Here's some more code where we extract characters at particular positions in a string, using indices.

# %%
#store it
testdatetime = times[0]['datetime']
#now extract the first 4 characters
print(testdatetime[0:4])
#and the characters from position 8 to 9 (the month)
print(testdatetime[8:10])
#and the characters from position 5 to 6 (the day)
#converting to an integer at the same time
print(int(testdatetime[5:7]))
# Out:
# 2023
# 04
# 8

# %%
#create 4 empty lists
datetimes = []
years = []
days = []
months = []

#loop through those <time> tag matches
for i in times:
  #extract the datetime= value
  casedate = i['datetime']
  #add to the datetimes list
  datetimes.append(casedate)
  #'slice' the string to extract the year, month and day, adding each to a different list
  years.append(int(casedate[0:4]))
  months.append(int(casedate[5:7]))
  days.append(int(casedate[8:10]))

# %% [markdown]
# ## Bonus: grabbing the link URL
#
# The same principles can be applied to extract the URL that each case title linked *to*.
#
# In this case we have a little problem, because we targeted the `<div>` tag when scraping the case titles, but the `<div>` tag doesn't contain the URL that each case title linked to - that information is contained inside an `<a>` tag, which is a **child** of the `<div>` tag.
#
# The good news is that we can use `.select()` on these results too.
#
# For example:

# %%
#grab all the <div> tags with class="gem-c-document-list__item-title"
divswewant = soup.select('div[class="gem-c-document-list__item-title"]')
#grab all the <a> tags inside the first match
print(divswewant[0].select('a'))
#drill down to the first match (there's only one)
print(divswewant[0].select('a')[0])
#grab the href= attribute value from that
print(divswewant[0].select('a')[0]['href'])
# Out:
# [<a class="govuk-link" data-ecommerce-index="1" data-ecommerce-path="/employment-tribunal-decisions/ms-i-m-de-araujo-ramos-fernandes-v-eden-brook-home-care-ltd-3205112-slash-2022" data-ecommerce-row="1" data-ga4-ecommerce-path="/employment-tribunal-decisions/ms-i-m-de-araujo-ramos-fernandes-v-eden-brook-home-care-ltd-3205112-slash-2022" data-track-action="Employment tribunal decisions.1" data-track-category="navFinderLinkClicked" data-track-label="/employment-tribunal-decisions/ms-i-m-de-araujo-ramos-fernandes-v-eden-brook-home-care-ltd-3205112-slash-2022" data-track-options='{"dimension28":50,"dimension29":"Ms I M de Araújo Ramos Fernandes v Eden Brook Home Care Ltd: 3205112/2022"}' href="/employment-tribunal-decisions/ms-i-m-de-araujo-ramos-fernandes-v-eden-brook-home-care-ltd-3205112-slash-2022">Ms I M de Araújo Ramos Fernandes v Eden Brook Home Care Ltd: 3205112/2022</a>]
# <a class="govuk-link" data-ecommerce-index="1" data-ecommerce-path="/employment-tribunal-decisions/ms-i-m-de-araujo-ramos-fernandes-v-eden-brook-home-care-ltd-3205112-slash-2022" data-ecommerce-row="1" data-ga4-ecommerce-path="/employment-tribunal-decisions/ms-i-m-de-araujo-ramos-fernandes-v-eden-brook-home-care-ltd-3205112-slash-2022" data-track-action="Employment tribunal decisions.1" data-track-category="navFinderLinkClicked" data-track-label="/employment-tribunal-decisions/ms-i-m-de-araujo-ramos-fernandes-v-eden-brook-home-care-ltd-3205112-slash-2022" data-track-options='{"dimension28":50,"dimension29":"Ms I M de Araújo Ramos Fernandes v Eden Brook Home Care Ltd: 3205112/2022"}' href="/employment-tribunal-decisions/ms-i-m-de-araujo-ramos-fernandes-v-eden-brook-home-care-ltd-3205112-slash-2022">Ms I M de Araújo Ramos Fernandes v Eden Brook Home Care Ltd: 3205112/2022</a>
# /employment-tribunal-decisions/ms-i-m-de-araujo-ramos-fernandes-v-eden-brook-home-care-ltd-3205112-slash-2022

# %% [markdown]
# Once we've got that working with one item, we can put it inside a list to create a new loop.

# %%
#create an empty list
url_list = []

#loop through the div matches
for i in divswewant:
  #select <a> tags inside that, and grab the first match
  atag = i.select('a')[0]
  #extract the URL inside href=""
  hrefvalue = atag['href']
  #add it to our list
  url_list.append(hrefvalue)

#check the first 5 results
url_list[:5]
# Out:
# ['/employment-tribunal-decisions/ms-i-m-de-araujo-ramos-fernandes-v-eden-brook-home-care-ltd-3205112-slash-2022',
#  '/employment-tribunal-decisions/mrs-p-marques-v-just-kidd-inn-ltd-3200680-slash-2023',
#  '/employment-tribunal-decisions/mrs-k-janusz-v-abc-distribution-ltd-3200710-slash-2023',
#  '/employment-tribunal-decisions/mr-d-singh-v-wanis-management-services-llp-3200018-slash-2023',
#  '/employment-tribunal-decisions/mr-a-sesay-v-bardwood-support-services-ltd-3205655-slash-2022']

# %% [markdown]
# ## Loop to store these in the dataframe too
#
# We can expand the earlier code to include all four lists we created.

# %%
#create a new dataframe which uses those two lists as its two columns
casedataframe = pd.DataFrame({"case name" : casetitles,
                              "date" : datelist,
                              "datetime":timeslist,
                              "url": url_list})

#show the first 5 rows
casedataframe[:5]
# Out:
#                                            case name            date  \
# 0   Ms I M de Araújo Ramos Fernandes v Eden Brook...   4 August 2023
# 1   Mrs P Marques v Just Kidd Inn Ltd: 3200680/20...  15 August 2023
# 2   Mrs K Janusz v ABC Distribution Ltd: 3200710/...  15 August 2023
# 3   Mr D Singh v Wanis Management Services LLP: 3...   2 August 2023
# 4   Mr A Sesay v Bardwood Support Services Ltd: 3...  15 August 2023
#
#      datetime                                                url
# 0  2023-08-04  /employment-tribunal-decisions/ms-i-m-de-arauj...
# 1  2023-08-15  /employment-tribunal-decisions/mrs-p-marques-v...
# 2  2023-08-15  /employment-tribunal-decisions/mrs-k-janusz-v-...
# 3  2023-08-02  /employment-tribunal-decisions/mr-d-singh-v-wa...
# 4  2023-08-15  /employment-tribunal-decisions/mr-a-sesay-v-ba...
