# %% [markdown]
# # Creating functions in Python (for scraping)
#
# In previous notebooks we covered:
#
# * How to create variables in Python (to store things like URLs for scraping, and the data from pages that we scrape);
# * How to loop through lists (in order to scrape or store each item in that list, for example); and
# * How to create data frames using `pandas` (to store the scraped data).
#
# Now we're going to bring those together into a final multi-page scraper by creating our own **functions**.
#
# We've used functions already such as `range()` and `len()`. These are **built-in functions** that come with Python. We've also used functions from libraries, like `requests.get()` and `pd.DataFrame()`.
#
# You can create your own function - a **user-defined function** - with the `def` command like so:

# %%
def sayhello():
  print("hello")

# %% [markdown]
# The `def` command is followed by:
#
# * The name of the function
# * Parentheses (which can contain any ingredients that you want to use but in this example don't)
# * A colon, and
# * Indented lines of code underneath which will run when the function is used
#
# The name of the function is entirely up to you, but try to make it distinctive and meaningful.
#
# We will explain the other parts as we begin to create a function below, but note for now that when you create the function nothing appears to happen.
#
# Of course something *has* happened when you run the code above: a function has been created and can now be used.

# %% [markdown]
# ## 'Calling' a function
#
# Using a function is referred to as 'calling' it.
#
# This is how you **call** a function:

# %%
sayhello()
# Out:
# hello

# %% [markdown]
# Basically it's like any other function: you type the name of the function, followed by parentheses containing any ingredients it needs. Even if the function doesn't need any ingredients, you still use (empty) parentheses.

# %% [markdown]
# ## Creating a function with ingredients
#
# Our example so far didn't have any ingredients, so let's create one that does.

# %%
def print_this_word(thisword):
  print(thisword)

# %% [markdown]
# This time we've put a word inside the parentheses: `thisword`
#
# In a way, we've created a variable to store whatever ingredient is used when someone calls this function. (This is called a **parameter**.)
#
# That variable is then used in the code below: `print(thisword)`
#
# To see what happens, let's use that function:

# %%
print_this_word("pumpkin")
# Out:
# pumpkin

# %% [markdown]
# Now let's break down what happens when that line of code is run:
#
# 1. First, it **calls** the function `print_this_word`
# 2. Then it gives it an ingredient: the string "pumpkin". This is called **passing** an **argument**
# 3. When the function was written, it called that ingredient `thisword`, so the string "pumpkin" is stored in a variable called `thisword`
# 4. As the function code runs, it accesses that variable inside a `print()` command, so the contents of that variable ("pumpkin" this time) are printed

# %% [markdown]
# ## Creating a function that **returns** something
#
# Our scraper above only prints something, but often you want a scraper to do something (such as perform a calculation, or scrape a page) and then **return** the results.
#
# Here's an example:

# %%
#define a new function called 'addtwonumbers' which has 2 parameters (ingredients)
def addtwonumbers(numone, numtwo):
  #the two parameters are added together and stored in 'total'
  total = numone+numtwo
  #the function returns that value
  return(total)

# %% [markdown]
# You can see that this function has *two* ingredients (parameters): `numone` and `numtwo`, separated by a comma. The function adds those two together, and stores it in a new variable called `total`. Finally it specifies to `return()` the contents of that variable.
#
# Here's that function being used:

# %%
whatisit = addtwonumbers(3,8)
print(whatisit)
# Out:
# 11

# %% [markdown]
# You can see that the first line runs the `addtwonumbers()` function and **passes** it two ingredients: two numbers, 3 and 8.
#
# The function runs, adds those two numbers together, and *returns* the result to the variable that it was being used to create: `whatisit`.
#
# We then print that.
#
# Returning information from a function can be incredibly powerful: in the example above it was just a number that was returned, but you can return lists, dictionaries, multiple items, and, among other things, data frames - which is what happens next...

# %% [markdown]
# ## Why you might need a function for a scraper
#
# It's all very nice adding numbers but what's that got to do with scraping?
#
# Well, functions are useful if you need to run code more than once.
#
# If your scraper needs to run on more than one page then that's what you're going to have to do: run the same code for every page you scrape.
#
# In that situation you might want to do something like the following:
#
# * Loop through a list of URLs
# * 'Pass' the URL to a scraper function, which runs all the scraping code
# * The function then 'returns' some results of that (for example, a dataframe of data)
# * You store that result in a variable, and perhaps add it to a larger dataframe which grows as the loop goes through each URL in the list

# %% [markdown]
# ## Creating a scraper function
#
# The good news is that if you've written code that works scraping one page, it's relatively straightforward to put that into a function.
#
# Here's the code that we used in the previous notebook to scrape [employment tribunal decisions](https://www.gov.uk/employment-tribunal-decisions)
#
# We will put the importing of libraries in a separate code block because it's not a good idea to import libraries inside a function - they should only be imported once.

# %%
#importing requests to fetch URLs
import requests
#importing beautiful soup's library for drilling into webpages
from bs4 import BeautifulSoup
#and pandas for storing data
import pandas as pd

# %%
#fetch URL
page = requests.get("https://www.gov.uk/employment-tribunal-decisions")

#command beautiful soup to parse the page
soup = BeautifulSoup(page.content,'html.parser')

#grab all the <div> tags with class="gem-c-document-list__item-title"
divswewant = soup.select('div[class="gem-c-document-list__item-title"]')
#this grabs the <time> tags
times = soup.select('time')

#create an empty list
casetitles = []

#loop through the divswewant list
for i in divswewant:
  #extract the text
  casename = i.get_text()
  #add the text and link to the previously empty lists
  casetitles.append(casename)

#create an empty list
datelist = []

#loop through the divswewant list
for i in times:
  #extract the text
  timetext = i.get_text()
  #add the text and link to the previously empty lists
  datelist.append(timetext)

#create a new dataframe which uses those two lists as its two columns
casedataframe = pd.DataFrame({"case name" : casetitles,
                              "date" : datelist})

# %% [markdown]
# If we want to run that scraper on other pages, all the code would be exactly the same apart from the URL.
#
# That URL, then, should become the only ingredient that the function needs to be given.
#
# Here's that code as a function, then.

# %%
#define a function - it takes one ingredient and calls it 'theurl'
def scrapepage(theurl):
  #fetch URL from that 'theurl'
  page = requests.get(theurl)
  #command beautiful soup to parse the page
  soup = BeautifulSoup(page.content,'html.parser')
  #grab all the <div> tags with class="gem-c-document-list__item-title"
  divswewant = soup.select('div[class="gem-c-document-list__item-title"]')
  #this grabs the <time> tags
  times = soup.select('time')
  #create an empty list
  casetitles = []
  #loop through the divswewant list
  for i in divswewant:
    #extract the text
    casename = i.get_text()
    #add the text and link to the previously empty lists
    casetitles.append(casename)
  #create an empty list
  datelist = []
  #loop through the divswewant list
  for i in times:
    #extract the text
    timetext = i.get_text()
    #add the text and link to the previously empty lists
    datelist.append(timetext)
  #create a new dataframe which uses those two lists as its two columns
  casedataframe = pd.DataFrame({"case name" : casetitles,
                                "date" : datelist})
  #return that dataframe to whatever called the function
  return(casedataframe)

# %% [markdown]
# To create this function we've essentially taken all the important code from before and indented it under the line `def scrapepage(theurl):`
#
# That first line transforms our previous code into something **reusable** by doing two things: giving a name to it (`scrapepage`); and giving a name to the URL we want to scrape (`theurl`).
#
# There's one other extra line too, right at the end: `return(casedataframe)` ensures that the results of the scraper are passed back to whatever calls this function.
#
# Something else to highlight: the function contains some `for` loops as well, which means there are two levels of indents in the code: all the code inside the function is indented, and then the `for` loop code inside *that* is indented one more time.

# %% [markdown]
# ## Testing the scraper function
#
# We can test the function on the same page to see if it works.

# %%
#run the function on the page
#the function 'returns' a dataframe, so we need to store that in a variable
storetheresults = scrapepage("https://www.gov.uk/employment-tribunal-decisions")
#print the variable containing the results
print(storetheresults)
# Out:
#                                             case name              date
# 0    Mr A Male v Airbus Operations Ltd: 1601482/20...     9 August 2023
# 1    Mrs E Petrelli v Tapas Twist Ltd: 1600374/2023\n     9 August 2023
# 2    Mr J Nash v Purple Dog Company.com Ltd: 16001...    11 August 2023
# 3    Mrs A Abhyankar v Cardiff and Vale University...    14 August 2023
# 4    Mr W Moyo v Co-Operative Group Ltd: 1311317/2...    11 August 2023
# 5    G Tinubu and others v Warwick Independent Sch...    17 August 2023
# 6    Mr D Mpehla v Central Heating Hub Ltd (in Vol...    16 August 2023
# 7    Mr R Brown v Royal Mail Group Ltd: 1302178/20...    15 August 2023
# 8    Mr Omole v Bannatyne Fitness Ltd: 1303948/2023\n    15 August 2023
# 9     Mr C Coleman v Tesco Stores Ltd: 1304434/2021\n    15 August 2023
# 10    Mr I Girling v DHL Services Ltd: 1303069/2023\n    15 August 2023
# 11   Mr A Guice v 24/7 Plumbing & Gas (UK) Ltd: 13...     13 March 2023
# 12   Mr E Allen and  Mr J Dunphy v Birmingham City...    15 August 2023
# 13   Mr D Farrell v Shaw Trust Ltd and Mr C Luck: ...   31 October 2022
# 14   Ms B Kumari v Aspiration Training Ltd: 130222...    15 August 2023
# 15   Ms D Bennett and Others v UCLA Ltd - 1301722/...      31 July 2023
# 16   Miss A Tussadiq V Optimus Law Ltd: 1308432/20...  24 February 2023
# 17              Dr C Mallon v MZA Ltd: 1404406/2021\n      21 July 2023
# 18   Mr Y Iqbal v Wokingham Borough Council: 33213...    16 August 2023
# 19   Mr A Hayat v Islamic Educational and Recreati...       25 May 2023
# 20   Mr T Tawfiq v Invent Enterprises Ltd: 3312998...       7 June 2023
# 21   Miss M Fretes v T Jegajeevan T/a Happy Times ...      12 July 2023
# 22   Mrs N Choudhary v Emma Victoria Ltd T/a Farnh...  17 November 2022
# 23   Mr C Wise v Ecoserv FM Group Ltd: 3301564/2023\n      19 July 2023
# 24          Mr K Takacs v Verogen Ltd: 3304298/2023\n      20 July 2023
# 25   Miss S Miah v Shared Services Connected Ltd: ...    16 August 2023
# 26   Miss I Geafar v Management and Training Corpo...    14 August 2023
# 27   Mr M Ford and others v Suez Industrial Water ...     9 August 2023
# 28   Mr M Mehmet and others v Medsun Food Ltd: 330...    11 August 2023
# 29   J Clarke v Marks and Spencer plc: 3313186/2022\n    12 August 2023
# 30   Mrs S Cook v Turning Point and others: 331163...    10 August 2023
# 31   Miss K Raymond v Hightown Housing Association...    11 August 2023
# 32   Mr S Shah v Alpha Response 2004 Ltd T/a Red S...    14 August 2023
# 33   Mr A Abuinsair v Barnhill Community High Scho...    14 August 2023
# 34            Mr G Dredd v Zirkon Ltd: 3310720/2021\n      31 July 2023
# 35   Mr J Collard v Plaza Premium Lounge (UK) Ltd:...       6 June 2023
# 36   Ms I M de Araújo Ramos Fernandes v Eden Brook...     4 August 2023
# 37   Mrs P Marques v Just Kidd Inn Ltd: 3200680/20...    15 August 2023
# 38   Mrs K Janusz v ABC Distribution Ltd: 3200710/...    15 August 2023
# 39   Mr D Singh v Wanis Management Services LLP: 3...     2 August 2023
# 40   Mr A Sesay v Bardwood Support Services Ltd: 3...    15 August 2023
# 41   Miss S A Parminter v Evolve Child Care Ltd: 1...      27 July 2023
# 42   Ms S Skuse v Clyst Hydon Pub Company Ltd (in ...      27 July 2023
# 43    Mr S George v The Brandon Trust: 1403216/2022\n      28 July 2023
# 44   Mr P Thompson v Devon and Somerset Fire and R...      28 July 2023
# 45   Mr M O Klimecka v Customer Dedicated Logistic...      27 July 2023
# 46   Mr L Wilson v Urban Autos Ltd (In Liquidation...      28 July 2023
# 47   Mr E Reynolds v Call The Mechanic: 2401727/20...      27 July 2023
# 48       Mr D Manfield v B R Rail Ltd: 1401195/2023\n      27 July 2023
# 49   Mr A Badru v JAKK Security & Facility Managme...       18 May 2023

# %% [markdown]
# ## Calling the scraper function on multiple pages
#
# Now let's call that function on a bunch of pages.
#
# We now need a list of URLs. Sometimes that list is one we've already compiled - but in this situation we are going to have to generate it ourselves.
#
# A good tip here is to move to the second page that you want to scrape, and look at the URL. In that case, it looks like this:
#
# `https://www.gov.uk/employment-tribunal-decisions?page=2`
#
# We can see the page number is at the end of the URL. If we replace that `2` with `1` we are taken back to the first page of results, and so on.
#
# What we need, then, is a list of numbers to add to the end of that URL which otherwise stays the same.

# %% [markdown]
# ### Generating a list of page numbers
#
# We can generate a list of numbers using Python's `range()` function. This needs two ingredients - the start number and a number it will end before.
#
# It won't include that end number so, for example `range(1,10)` will go from 1 to 9, stopping short of 10.
#
# We know that our start number is `1`, but where should we end?
#
# In this case, the page actually tells us what the last page is: the 'Next page' link goes to '2 of 2075', so there are 2,075 pages.
#
# What about when that isn't the case? Sometimes websites give you the option to go to the last page of results, allowing you to see (in the URL for example) what the last page number is.
#
# If you can't do that, but the page tells you how many results there are, and you know how many results are on each page, you can calculate how many pages there should be by dividing one by the other.
#
# For example, if there are 2,105 results and 50 results per page, the calculation would be `2015/50` - which is 40.3: 40 pages of 50 results, plus a 41st page containing the last few. In other words, pages 1 to 41.

# %% [markdown]
# ### Adding page numbers to the URL
#
# The code to generate a list of page numbers from 1 to 2,075, then (remembering that it will stop short of the end number), would be:
#
# `range(1,2076)`
#
# Here's a first attempt at looping through those numbers and adding them to the URL `"https://www.gov.uk/employment-tribunal-decisions?page="` - it will create an error, which is important.

# %%
#loop through the numbers 1 to 2075
for i in range(1,2076):
  #add it to the end of a URL, and print it
  print("https://www.gov.uk/employment-tribunal-decisions?page="+i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-18a0fcb60dab> in <cell line: 2>()
#       2 for i in range(1,2076):
#       3   #add it to the end of a URL, and print it
# ----> 4   print("https://www.gov.uk/employment-tribunal-decisions?page="+i)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ### Turning numbers into strings
#
# The error we get here is:
#
# `TypeError: can only concatenate str (not "int") to str`
#
# This is trying to tell us that you can't combine (concatenate) integers and strings. You can only combine strings with strings.
#
# So the problem is that we are trying to add a number to a string.
#
# To fix that, we simply need to convert the number to a string first - and there's a basic function to do that: `str()`
#
# In our code, then we just need to tweak the line so that it adds the basic URL to `str(i)` - that is, our number (`i`) converted to a string.

# %%
#loop through the numbers 1 to 2075
for i in range(1,2076):
  #add it to the end of a URL, and print it
  print("https://www.gov.uk/employment-tribunal-decisions?page="+str(i))

# %% [markdown]
# ### Putting the function into the loop
#
# Now that we've solved that problem, we can start to apply the function to each URL as it loops through them.
#
# As there are so many URLs, it's a good idea not to do them all at first. While testing we might just loop through the first couple of pages.

# %%
#loop through the numbers 1 to 2
for i in range(1,3):
  #add it to the end of a URL,
  fullurl = "https://www.gov.uk/employment-tribunal-decisions?page="+str(i)
  #and print it
  print(fullurl)
  #run the scraper function, and store what's returned
  theseresults = scrapepage(fullurl)
  #print what was returned
  print(theseresults)
# Out:
# https://www.gov.uk/employment-tribunal-decisions?page=1
#                                             case name              date
# 0    Mr A Male v Airbus Operations Ltd: 1601482/20...     9 August 2023
# 1    Mrs E Petrelli v Tapas Twist Ltd: 1600374/2023\n     9 August 2023
# 2    Mr J Nash v Purple Dog Company.com Ltd: 16001...    11 August 2023
# 3    Mrs A Abhyankar v Cardiff and Vale University...    14 August 2023
# 4    Mr W Moyo v Co-Operative Group Ltd: 1311317/2...    11 August 2023
# 5    G Tinubu and others v Warwick Independent Sch...    17 August 2023
# 6    Mr D Mpehla v Central Heating Hub Ltd (in Vol...    16 August 2023
# 7    Mr R Brown v Royal Mail Group Ltd: 1302178/20...    15 August 2023
# 8    Mr Omole v Bannatyne Fitness Ltd: 1303948/2023\n    15 August 2023
# 9     Mr C Coleman v Tesco Stores Ltd: 1304434/2021\n    15 August 2023
# 10    Mr I Girling v DHL Services Ltd: 1303069/2023\n    15 August 2023
# 11   Mr A Guice v 24/7 Plumbing & Gas (UK) Ltd: 13...     13 March 2023
# 12   Mr E Allen and  Mr J Dunphy v Birmingham City...    15 August 2023
# 13   Mr D Farrell v Shaw Trust Ltd and Mr C Luck: ...   31 October 2022
# 14   Ms B Kumari v Aspiration Training Ltd: 130222...    15 August 2023
# 15   Ms D Bennett and Others v UCLA Ltd - 1301722/...      31 July 2023
# 16   Miss A Tussadiq V Optimus Law Ltd: 1308432/20...  24 February 2023
# 17              Dr C Mallon v MZA Ltd: 1404406/2021\n      21 July 2023
# 18   Mr Y Iqbal v Wokingham Borough Council: 33213...    16 August 2023
# 19   Mr A Hayat v Islamic Educational and Recreati...       25 May 2023
# 20   Mr T Tawfiq v Invent Enterprises Ltd: 3312998...       7 June 2023
# 21   Miss M Fretes v T Jegajeevan T/a Happy Times ...      12 July 2023
# 22   Mrs N Choudhary v Emma Victoria Ltd T/a Farnh...  17 November 2022
# 23   Mr C Wise v Ecoserv FM Group Ltd: 3301564/2023\n      19 July 2023
# 24          Mr K Takacs v Verogen Ltd: 3304298/2023\n      20 July 2023
# 25   Miss S Miah v Shared Services Connected Ltd: ...    16 August 2023
# 26   Miss I Geafar v Management and Training Corpo...    14 August 2023
# 27   Mr M Ford and others v Suez Industrial Water ...     9 August 2023
# 28   Mr M Mehmet and others v Medsun Food Ltd: 330...    11 August 2023
# 29   J Clarke v Marks and Spencer plc: 3313186/2022\n    12 August 2023
# 30   Mrs S Cook v Turning Point and others: 331163...    10 August 2023
# 31   Miss K Raymond v Hightown Housing Association...    11 August 2023
# 32   Mr S Shah v Alpha Response 2004 Ltd T/a Red S...    14 August 2023
# 33   Mr A Abuinsair v Barnhill Community High Scho...    14 August 2023
# 34            Mr G Dredd v Zirkon Ltd: 3310720/2021\n      31 July 2023
# 35   Mr J Collard v Plaza Premium Lounge (UK) Ltd:...       6 June 2023
# 36   Ms I M de Araújo Ramos Fernandes v Eden Brook...     4 August 2023
# 37   Mrs P Marques v Just Kidd Inn Ltd: 3200680/20...    15 August 2023
# 38   Mrs K Janusz v ABC Distribution Ltd: 3200710/...    15 August 2023
# 39   Mr D Singh v Wanis Management Services LLP: 3...     2 August 2023
# 40   Mr A Sesay v Bardwood Support Services Ltd: 3...    15 August 2023
# 41   Miss S A Parminter v Evolve Child Care Ltd: 1...      27 July 2023
# 42   Ms S Skuse v Clyst Hydon Pub Company Ltd (in ...      27 July 2023
# 43    Mr S George v The Brandon Trust: 1403216/2022\n      28 July 2023
# 44   Mr P Thompson v Devon and Somerset Fire and R...      28 July 2023
# 45   Mr M O Klimecka v Customer Dedicated Logistic...      27 July 2023
# 46   Mr L Wilson v Urban Autos Ltd (In Liquidation...      28 July 2023
# 47   Mr E Reynolds v Call The Mechanic: 2401727/20...      27 July 2023
# 48       Mr D Manfield v B R Rail Ltd: 1401195/2023\n      27 July 2023
# 49   Mr A Badru v JAKK Security & Facility Managme...       18 May 2023
# https://www.gov.uk/employment-tribunal-decisions?page=2
#                                             case name              date
# 0    Mrs N Hulait v Leicestershire Partnership NHS...       6 July 2023
# 1     Mr W Nowak v A Popat and others: 2600959/2022\n    14 August 2023
# 2        Miss D Evans v Only Care Ltd: 2600945/2023\n    15 August 2023
# 3    Ms C Josey v Intesa (Leicester) Ltd: 2602064/...    16 August 2023
# 4    Mr K L Haytack v Precedent Surveyors Ltd: 180...    16 August 2023
# 5    Mr J Mayanja v Bradford Metropolitan Borough ...    1 January 2022
# 6    Mrs S Messum v Bradford Management Services L...  19 December 2022
# 7    Mr N Rawle v Stakestar Ltd (in Voluntary Liqu...    16 August 2023
# 8    Miss M Tafa v Hull University Teaching Hospit...    11 August 2023
# 9    Mr S Blackburn v J Blackburn and Sons Ltd (In...     8 August 2023
# 10   Miss S Benn v Boots Management Services Ltd: ...    15 August 2023
# 11   Mrs C Cox and Mr M Jefferson v Neuro Case Man...    14 August 2023
# 12   Mr D Morgan v Orridge & Company Ltd: 8000039/...     4 August 2023
# 13   Ms M Mccormick v North Lanarkshire Women’s Ai...    11 August 2023
# 14   Mr A Gorski v Miller Fabrications Ltd: 410749...      21 July 2023
# 15   Mr W Purcell v Screen Ink and Solvent Supplie...  12 February 2023
# 16         Mr T O'Donnell v L Howlett: 2406177/2023\n     2 August 2023
# 17   Mr R Ives v Dekko Window Systems: 2401504/2023\n     7 August 2023
# 18   Mr P R Bell v GT Tyres Cumbria Ltd: 2404476/2...     3 August 2023
# 19   Mr M Parks v Optimal-UK Logistics Ltd (in Cre...     3 August 2023
# 20   Mr M N Lomax v Euxton Tile Supplies Ltd: 2410...     4 August 2023
# 21   Mrs P Harris v Cotton Traders Ltd: 2501697/20...      14 July 2023
# 22   Mr M A Ishfaq v Mediscan Diagnostic Services ...     7 August 2023
# 23              Mrs L Futers v EE Ltd: 2502279/2022\n      28 July 2023
# 24   Mr M Lupyna and Mr V Lupyna v Safe Strip UK L...    11 August 2023
# 25   Mr A Laverick v Magnit Global GRI Ltd and Blu...      10 July 2023
# 26   Mr I Holt v Cabin Crew International Ltd: 240...     8 August 2023
# 27   S Hathaway v Secretary of State for Work and ...      11 July 2023
# 28   Mr I Haq v United Learning Trust and Others: ...    10 August 2023
# 29   Mr D Taheri v Aprite (GB) Ltd T/a Westway Nis...  12 November 2019
# 30           Mr CS Cheng v Garic Ltd:  2408057/2021\n     7 August 2023
# 31   Mr B Webster v Diamond Bus (North West) Ltd: ...      19 July 2023
# 32   Miss C Burrows v Direct Accident Management: ...     8 August 2023
# 33   Mr S Ahmed and Miss B Ahmed v T B Shiffer and...     9 August 2023
# 34   Ms K Thornton v Riviera Multimedia Ltd: 18007...     4 August 2023
# 35            Mr R Oliver v D Andrews: 1803155/2023\n     3 August 2023
# 36   Mr D Hoyle v P and J Annakin, Executors of D ...     8 August 2023
# 37   Mr A S A Rashid v The Sheffield College: 6000...    11 August 2023
# 38   Ms J Williams v The Compound Newham Street Gy...      17 July 2023
# 39     Ms A Pearce v RB - Allsort Ltd: 3201043/2023\n    15 August 2023
# 40           Mr D Ralfa v Mr A Aarons: 3205977/2022\n      17 July 2023
# 41   Mr A Azeem v Crownguard Security Services Ltd...      14 July 2023
# 42       C Roberts v J D Wetherspoons: 2301864/2022\n    11 August 2023
# 43   I Omoregbee v St John's Nursing Home Ltd: 230...     9 August 2023
# 44   Mr S Harrington v ABM Aviation UK Ltd: 230018...     27 April 2021
# 45   Ms N Cross-Padden v Kitrinos Healthcare (Char...     4 August 2023
# 46   Mr R Cardiff and others v London Stock Photog...      25 July 2023
# 47   Y Savchuk and others v R.M.I. Property Mainte...     2 August 2023
# 48   Mr O Mohammed v Hendrie Legal Ltd: 4101383/20...     8 August 2023
# 49   Mr H Ibrahim v Stanmore Implants Worldwide Lt...      27 July 2023

# %% [markdown]
# ### Storing multiple results in a single dataframe
#
# That seems to work on two pages - but each time the loop runs the results of the previous iteration are overwritten.
#
# We need a way to save the results as we go along - much as we did with `.append()` when we added items to a list.
#
# The equivalent with a dataframe is the function `concat()`. This is a `pandas` function, so it's prefixed with `pandas` or `pd` depening on whether the library was renamed when it was imported, so you would write: `pd.concat()`
#
# The `concat()` function can take a number of ingredients, but in this situation we only need to give it one thing: a list of the dataframes it is going to combine.
#
# In this case we want to create an empty dataframe before the loop begins, and then each time the loop runs, combine that dataframe with the dataframe that gets returned by the function as it scrapes each URL, and overwrite the empty dataframe with the results.
#
# This can be a little difficult to get your head around, so let's walk through what happens here.
#
# * First we have an empty dataframe - let's call it `fillme`
# * The first time the loop runs, we grab the dataframe for page 1, combine it with `fillme`, and then *overwrite* `fillme` with the results
# * The second time the loop runs, we grab the dataframe for page 2, combine it with `fillme` (which now holds page 1), and ovewrite `fillme` ith the results
# * The third time the loop runs, we grab the dataframe for page 3, combine it with `fillme` (which now holds page 1 *and* page 2), and ovewrite `fillme` ith the results
#
# ...and so on.
#
# Here's that incorporated into our code.

# %%
#create an empty dataframe
fillme = pd.DataFrame()

#loop through the numbers 1 to 2
for i in range(1,3):
  #add it to the end of a URL,
  fullurl = "https://www.gov.uk/employment-tribunal-decisions?page="+str(i)
  #and print it
  print(fullurl)
  #run the scraper function, and store what's returned
  theseresults = scrapepage(fullurl)
  #print what was returned
  #print(theseresults)
  fillme = pd.concat([fillme,theseresults])

fillme
# Out:
# https://www.gov.uk/employment-tribunal-decisions?page=1
# https://www.gov.uk/employment-tribunal-decisions?page=2
#                                             case name            date
# 0    Mr A Male v Airbus Operations Ltd: 1601482/20...   9 August 2023
# 1    Mrs E Petrelli v Tapas Twist Ltd: 1600374/2023\n   9 August 2023
# 2    Mr J Nash v Purple Dog Company.com Ltd: 16001...  11 August 2023
# 3    Mrs A Abhyankar v Cardiff and Vale University...  14 August 2023
# 4    Mr W Moyo v Co-Operative Group Ltd: 1311317/2...  11 August 2023
# ..                                                ...             ...
# 45   Ms N Cross-Padden v Kitrinos Healthcare (Char...   4 August 2023
# 46   Mr R Cardiff and others v London Stock Photog...    25 July 2023
# 47   Y Savchuk and others v R.M.I. Property Mainte...   2 August 2023
# 48   Mr O Mohammed v Hendrie Legal Ltd: 4101383/20...   8 August 2023
# 49   Mr H Ibrahim v Stanmore Implants Worldwide Lt...    27 July 2023
#
# [100 rows x 2 columns]

# %% [markdown]
# ### The code explained
#
# Creating an empty dataframe is done with this line of code:
#
# `fillme = pd.DataFrame()`
#
# Here we use the `pandas` function `DataFrame()` but we leave the parentheses empty (no ingredients) which means it will create an empty dataframe.
#
# That empty dataframe is stored in a variable called `fillme`.
#
# Inside the loop the function is called, and the results stored, in this line, which creates another dataframe object, `theseresults`:
#
# `theseresults = scrapepage(fullurl)`
#
# So at this point we have two dataframes:
#
# * `fillme`, which we created before the loop started; and
# * `theseresults`, which will only exist momentarily until the loop runs again.
#
# The final line before the loop runs again, then, is this:
#
# `fillme = pd.concat([fillme,theseresults])`
#
# Start to the right of the equals sign. Here we can see the `concat()` function being used - and the ingredient it is given is a list:
#
# `[fillme,theseresults]`
#
# That's a list of the two dataframes we want to concatenate, or combine.
#
# Once combined, the resulting dataframe is assigned to the variable before the equals sign, `fillme`.
#
# So, what was previously empty is overwritten with those results.
#
# When the loop is run on all the pages it will overwrite that dataframe hundreds of times, each time combining the version with all the previous pages' data, with the latest page's data, until it finishes looping.

# %% [markdown]
# ## Export the results as a CSV
#
# Once you have data you want to look at in a spreadsheet, you can export the dataframe as a CSV using the `.to_csv()` method.
#
# This needs to be added the the name of the dataframe variable, with the name of the CSV in parentheses (don't forget to put it in quotation marks or inverted commas)
#
# That file should then be available in the Files area on the left in Colab (the folder icon).

# %%
#export results as a CSV
fillme.to_csv('tribunaldata.csv')

# %% [markdown]
# ## Applying this to 'detail' links
#
# The principles outlined above could be used to grab information from 'detail' links that provide more information on each case.
#
# In that scenario, you would:
#
# * Scrape the links to each tribunal detail page and store in a list (or columnn in a dataframe)
# * Write a function to scrape the detail page
# * Loop through the list/column of detail links, and run the function on each, returning data which can be stored in a larger dataframe

# %% [markdown]
# ## Improvement 1: adding a delay (throttling)
#
# We can change the scraper so that it pauses between each page. To do this we need the `time` library.

# %%
#Import the time library to use its sleep() function
import time

# %% [markdown]
# We can then use the `sleep()` function from that library, which [stops the code running for a specified number of seconds](https://www.programiz.com/python-programming/time/sleep). So to pause for three seconds it might be written like so:
#
# `time.sleep(3)`
#
# That can be inserted into loop that calls the scraping function (or, if the scraping function scrapes more than one page, you can insert it there to pause between each page):

# %%
#create an empty dataframe
fillme = pd.DataFrame()

#loop through the numbers 1 to 2,075
for i in range(1,2075):
  #add it to the end of a URL,
  fullurl = "https://www.gov.uk/employment-tribunal-decisions?page="+str(i)
  #and print it
  print(fullurl)
  #run the scraper function, and store what's returned
  theseresults = scrapepage(fullurl)
  #print what was returned
  #print(theseresults)
  fillme = pd.concat([fillme,theseresults])
  print("waiting 3 seconds before next scrape")
  #Sleep for 3 seconds before looping again
  time.sleep(3)
# Out:
# https://www.gov.uk/employment-tribunal-decisions?page=1
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=2
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=3
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=4
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=5
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=6
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=7
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=8
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=9
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=10
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=11
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=12
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=13
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=14
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=15
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=16
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=17
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=18
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=19
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=20
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=21
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=22
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=23
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=24
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=25
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=26
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=27
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=28
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=29
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=30
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=31
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=32
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=33
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=34
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=35
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=36
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=37
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=38
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=39
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=40
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=41
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=42
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=43
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=44
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=45
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=46
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=47
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=48
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=49
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=50
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=51
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=52
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=53
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=54
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=55
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=56
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=57
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=58
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=59
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=60
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=61
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=62
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=63
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=64
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=65
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=66
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=67
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=68
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=69
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=70
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=71
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=72
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=73
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=74
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=75
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=76
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=77
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=78
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=79
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=80
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=81
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=82
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=83
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=84
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=85
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=86
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=87
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=88
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=89
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=90
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=91
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=92
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=93
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=94
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=95
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=96
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=97
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=98
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=99
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=100
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=101
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=102
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=103
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=104
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=105
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=106
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=107
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=108
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=109
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=110
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=111
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=112
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=113
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=114
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=115
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=116
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=117
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=118
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=119
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=120
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=121
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=122
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=123
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=124
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=125
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=126
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=127
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=128
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=129
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=130
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=131
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=132
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=133
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=134
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=135
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=136
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=137
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=138
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=139
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=140
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=141
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=142
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=143
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=144
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=145
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=146
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=147
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=148
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=149
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=150
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=151
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=152
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=153
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=154
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=155
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=156
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=157
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=158
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=159
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=160
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=161
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=162
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=163
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=164
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=165
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=166
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=167
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=168
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=169
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=170
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=171
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=172
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=173
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=174
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=175
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=176
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=177
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=178
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=179
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=180
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=181
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=182
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=183
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=184
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=185
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=186
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=187
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=188
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=189
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=190
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=191
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=192
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=193
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=194
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=195
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=196
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=197
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=198
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=199
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=200
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=201
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=202
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=203
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=204
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=205
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=206
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=207
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=208
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=209
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=210
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=211
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=212
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=213
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=214
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=215
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=216
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=217
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=218
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=219
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=220
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=221
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=222
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=223
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=224
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=225
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=226
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=227
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=228
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=229
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=230
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=231
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=232
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=233
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=234
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=235
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=236
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=237
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=238
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=239
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=240
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=241
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=242
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=243
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=244
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=245
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=246
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=247
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=248
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=249
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=250
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=251
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=252
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=253
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=254
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=255
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=256
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=257
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=258
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=259
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=260
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=261
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=262
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=263
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=264
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=265
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=266
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=267
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=268
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=269
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=270
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=271
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=272
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=273
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=274
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=275
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=276
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=277
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=278
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=279
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=280
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=281
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=282
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=283
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=284
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=285
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=286
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=287
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=288
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=289
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=290
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=291
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=292
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=293
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=294
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=295
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=296
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=297
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=298
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=299
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=300
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=301
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=302
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=303
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=304
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=305
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=306
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=307
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=308
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=309
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=310
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=311
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=312
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=313
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=314
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=315
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=316
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=317
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=318
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=319
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=320
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=321
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=322
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=323
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=324
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=325
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=326
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=327
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=328
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=329
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=330
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=331
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=332
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=333
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=334
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=335
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=336
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=337
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=338
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=339
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=340
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=341
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=342
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=343
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=344
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=345
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=346
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=347
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=348
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=349
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=350
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=351
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=352
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=353
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=354
# waiting 3 seconds before next scrape
# https://www.gov.uk/employment-tribunal-decisions?page=355
# waiting 3 seconds before next scrape
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-1be80c0dc0ff> in <cell line: 5>()
#      15   print("waiting 3 seconds before next scrape")
#      16   #Sleep for 3 seconds before looping again
# ---> 17   time.sleep(3)
#
# KeyboardInterrupt:
